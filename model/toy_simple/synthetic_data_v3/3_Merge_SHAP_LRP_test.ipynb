# %% [markdown]
# ## Merge results from SHAP and LRP in test

# %%
import pickle

# %%
SEQ_LEN = 30
MODEL_NAME = "lstm-att-lrp"
best_epoch = 5

# %%
shap_results_path = f"./output/time_diff_toy_dataset_v3/event_based/{SEQ_LEN}/{MODEL_NAME}/test_results_shap_5.pkl"
lrp_results_path = f"./output/time_diff_toy_dataset_v3/event_based/{SEQ_LEN}/{MODEL_NAME}/test_results_lrp_5.pkl"

output_path = f"./output/time_diff_toy_dataset_v3/event_based/{SEQ_LEN}/{MODEL_NAME}/test_results_all_5.pkl"

# %%
with open(shap_results_path, 'rb') as fp:
    shap_results = pickle.load(fp)
    
with open(lrp_results_path, 'rb') as fp:
    lrp_results = pickle.load(fp)

# %%
lrp_results[best_epoch]
# Out:
# {'6ZOB2DEVY7': {'label': tensor([0]),
#   'pred': 1.8426749051979867,
#   'imp':     lrp_scores  idx  seq_idx                   token  att_weights
#   0    -0.004621   17        0           dental_exam_N     0.012767
#   1    -0.004601   17        1           dental_exam_N     0.018179
#   2     0.334022    8        2              eye_exam_N     0.024975
#   3     0.248345   27        3           sleep_apnea_H     0.028488
#   4    -0.006096   10        4             cold_sore_N     0.033411
#   5     0.245898   30        5              troponin_H     0.036757
#   6     0.527560   14        6            cut_finger_N     0.038834
#   7    -0.005007   22        7          ankle_sprain_N     0.039472
#   8     0.002656   21        8  ventricular_aneurysm_A     0.040978
#   9     0.644247    8        9              eye_exam_N     0.041668
#   10   -0.804630    7       10              headache_N     0.040377
#   11   -0.033287    6       11                myopia_N     0.039762
#   12    0.013179   13       12             hay_fever_N     0.039562
#   13   -0.012890   20       13       annual_physical_N     0.039268
#   14   -0.035099    6       14                myopia_N     0.038771
#   15   -0.008513    9       15        peanut_allergy_N     0.036457
#   16   -0.016730   12       16           quad_injury_N     0.038327
#   17    0.419986   15       17              backache_N     0.039640
#   18   -0.001498   22       18          ankle_sprain_N     0.040413
#   19   -0.034909    6       19                myopia_N     0.042938
#   20   -0.002967   17       20           dental_exam_N     0.045172
#   21    0.402712   15       21              backache_N     0.046691
#   22   -0.801682    2       22             foot_pain_N     0.047004
#   23   -0.010902    9       23        peanut_allergy_N     0.049140
#   24    0.606881   14       24            cut_finger_N     0.050997
#   25   -0.013440   10       25             cold_sore_N     0.049950},
#  'H0JJPVS9NC': {'label': tensor([0]),
#   'pred': 0.7655713524260574,
#   'imp':     lrp_scores  idx  seq_idx                    token  att_weights
#   0     0.010334    3        0           ingrown_nail_N     0.035767
#   1    -0.014616   20        1        annual_physical_N     0.036908
#   2     0.871447    8        2               eye_exam_N     0.039688
#   3    -0.017412   20        3        annual_physical_N     0.040544
#   4    -0.028875   18        4  electrolyte_imbalance_H     0.039540
#   5    -0.013930   10        5              cold_sore_N     0.040649
#   6     0.023327   13        6              hay_fever_N     0.042046
#   7     0.596584   37        7              diuretics_U     0.044026
#   8    -0.021646    5        8               ACL_tear_N     0.045443
#   9    -0.010155   17        9            dental_exam_N     0.047692
#   10   -0.022534    5       10               ACL_tear_N     0.048943
#   11    0.665927   15       11               backache_N     0.050678
#   12   -0.009521   17       12            dental_exam_N     0.051860
#   13   -0.054836    6       13                 myopia_N     0.053928
#   14    0.017861   13       14              hay_fever_N     0.055045
#   15   -0.053733    6       15                 myopia_N     0.055750
#   16   -1.255890    2       16              foot_pain_N     0.054213
#   17   -0.018992    5       17               ACL_tear_N     0.053894
#   18   -0.022371   12       18            quad_injury_N     0.055157
#   19   -0.022264   10       19              cold_sore_N     0.054666
#   20    0.003587   22       20           ankle_sprain_N     0.053565},
#  'SJL4CASM58': {'label': tensor([0]),
#   'pred': 2.117125741750053,
#   'imp':     lrp_scores  idx  seq_idx                                 token  \
#   0    -0.004160   22        0                        ankle_sprain_N
#   1     0.242701    8        1                            eye_exam_N
#   2     0.287796   42        2  Percutaneous_Coronary_Intervention_U
#   3     0.314040    8        3                            eye_exam_N
#   4    -0.007292    5        4                            ACL_tear_N
#   5    -0.008321   20        5                     annual_physical_N
#   6     0.254635   15        6                            backache_N
#   7    -0.007678    5        7                            ACL_tear_N
#   8     0.261604   37        8                           diuretics_U
#   9     0.487495    8        9                            eye_exam_N
#   10   -0.005583    5       10                            ACL_tear_N
#   11   -0.008220    9       11                      peanut_allergy_N
#   12   -0.000920   17       12                         dental_exam_N
#   13   -0.007709   12       13                         quad_injury_N
#
#       att_weights
#   0      0.012890
#   1      0.023935
#   2      0.037794
#   3      0.050327
#   4      0.063466
#   5      0.074248
#   6      0.081047
#   7      0.087018
#   8      0.090492
#   9      0.091975
#   10     0.094193
#   11     0.097144
#   12     0.098843
#   13     0.096625  },
#  'NGCBRFR511': {'label': tensor([1]),
#   'pred': -1.1362655922828782,
#   'imp':     lrp_scores  idx  seq_idx                   token  att_weights
#   0    -0.020699    6        0                myopia_N     0.025547
#   1     0.579369    8        1              eye_exam_N     0.024224
#   2    -0.011640   20        2       annual_physical_N     0.024096
#   3    -0.004032   10        3             cold_sore_N     0.024311
#   4     0.495213   26        4          hypertension_A     0.023952
#   5    -0.041461    6        5                myopia_N     0.024618
#   6     0.013593    3        6          ingrown_nail_N     0.025945
#   7    -1.255071    2        7             foot_pain_N     0.030745
#   8     0.620900   15        8              backache_N     0.032844
#   9     0.000090   21        9  ventricular_aneurysm_A     0.039678
#   10   -0.009080   10       10             cold_sore_N     0.045291
#   11   -1.328002    7       11              headache_N     0.052872
#   12   -1.306841    7       12              headache_N     0.062393
#   13    0.883041   32       13           alchoholism_H     0.063546
#   14   -0.011449   22       14          ankle_sprain_N     0.068800
#   15    0.015089    3       15          ingrown_nail_N     0.067750
#   16    0.014061    3       16          ingrown_nail_N     0.066535
#   17   -0.004565   22       17          ankle_sprain_N     0.063869
#   18   -0.020524   20       18       annual_physical_N     0.062601
#   19    0.002015   13       19             hay_fever_N     0.060370
#   20   -0.004394   13       20             hay_fever_N     0.055941
#   21   -0.015516   20       21       annual_physical_N     0.054072},
#  '7RGUUPQBGO': {'label': tensor([0]),
#   'pred': 1.5758390531903312,
#   'imp':     lrp_scores  idx  seq_idx                                 token  \
#   0    -0.111439    6        0                              myopia_N
#   1    -0.131882    6        1                              myopia_N
#   2    -0.081552   12        2                         quad_injury_N
#   3    -3.858857    7        3                            headache_N
#   4    -0.046256   17        4                         dental_exam_N
#   5    -0.041179   17        5                         dental_exam_N
#   6    -0.024977   22        6                        ankle_sprain_N
#   7    -3.921919    7        7                            headache_N
#   8    -0.028043   17        8                         dental_exam_N
#   9    -0.073060   12        9                         quad_injury_N
#   10   -0.053506    5       10                            ACL_tear_N
#   11   -0.047202    9       11                      peanut_allergy_N
#   12    0.015567    3       12                        ingrown_nail_N
#   13    2.934138   46       13                           pacemaker_U
#   14    1.485883   15       14                            backache_N
#   15    2.549942   42       15  Percutaneous_Coronary_Intervention_U
#   16   -0.126870    6       16                              myopia_N
#   17    2.521440   14       17                          cut_finger_N
#   18    0.005127   17       18                         dental_exam_N
#   19    1.304735   15       19                            backache_N
#   20    2.206869   14       20                          cut_finger_N
#   21   -0.029087   13       21                           hay_fever_N
#   22    0.005607    3       22                        ingrown_nail_N
#   23   -1.729213    7       23                            headache_N
#   24    0.010662    3       24                        ingrown_nail_N
#   25    0.001045   17       25                         dental_exam_N
#
#       att_weights
#   0      0.017131
#   1      0.018180
#   2      0.018497
#   3      0.017124
#   4      0.017902
#   5      0.019764
#   6      0.022009
#   7      0.019963
#   8      0.020125
#   9      0.019800
#   10     0.019832
#   11     0.020234
#   12     0.021140
#   13     0.027399
#   14     0.036539
#   15     0.049558
#   16     0.058743
#   17     0.066053
#   18     0.067018
#   19     0.068092
#   20     0.068994
#   21     0.067639
#   22     0.063754
#   23     0.060081
#   24     0.058335
#   25     0.056095  },
#  'QSC37BJ6ST': {'label': tensor([1]),
#   'pred': -1.6792819770411778,
#   'imp':     lrp_scores  idx  seq_idx              token  att_weights
#   0    -0.004726   20        0  annual_physical_N     0.012262
#   1    -0.006009   20        1  annual_physical_N     0.011514
#   2     0.466716    8        2         eye_exam_N     0.010502
#   3    -0.676557   43        3    beta_blockers_U     0.013651
#   4    -0.663059    2        4        foot_pain_N     0.016362
#   5     0.678689   16        5        pneumonia_H     0.017436
#   6     0.035507   13        6        hay_fever_N     0.021222
#   7    -0.001107   10        7        cold_sore_N     0.022595
#   8    -0.882546    2        8        foot_pain_N     0.027425
#   9    -0.013443   20        9  annual_physical_N     0.026061
#   10   -0.002446   10       10        cold_sore_N     0.027947
#   11   -0.022521   12       11      quad_injury_N     0.029737
#   12   -0.038666    6       12           myopia_N     0.031725
#   13    0.013056    3       13     ingrown_nail_N     0.033918
#   14   -0.041197    6       14           myopia_N     0.036237
#   15   -0.042206    6       15           myopia_N     0.038556
#   16   -0.016422   20       16  annual_physical_N     0.041030
#   17   -0.013367   22       17     ankle_sprain_N     0.043309
#   18   -0.009506   10       18        cold_sore_N     0.045384
#   19    1.006492    8       19         eye_exam_N     0.045213
#   20   -1.196571    2       20        foot_pain_N     0.050234
#   21   -0.019169   20       21  annual_physical_N     0.048099
#   22   -1.181993    2       22        foot_pain_N     0.050408
#   23   -0.009398    9       23   peanut_allergy_N     0.050004
#   24   -0.016460    5       24         ACL_tear_N     0.055104
#   25   -1.140233    2       25        foot_pain_N     0.056861
#   26    0.946497   14       26       cut_finger_N     0.048906
#   27    0.862931   14       27       cut_finger_N     0.045491
#   28   -0.011695   20       28  annual_physical_N     0.042804},
#  'WCC172WBAR': {'label': tensor([1]),
#   'pred': -0.12732831975203568,
#   'imp':     lrp_scores  idx  seq_idx                    token  att_weights
#   0     0.724677   14        0             cut_finger_N     0.045939
#   1     0.470961   15        1               backache_N     0.044471
#   2    -0.014335   17        2            dental_exam_N     0.043805
#   3    -0.008855   10        3              cold_sore_N     0.043321
#   4    -0.016702   22        4           ankle_sprain_N     0.042943
#   5    -0.012114   10        5              cold_sore_N     0.042732
#   6    -0.037459   18        6  electrolyte_imbalance_H     0.042527
#   7     0.002864   21        7   ventricular_aneurysm_A     0.042754
#   8     1.107805   34        8    heart_valve_failure_A     0.041966
#   9    -1.595397    2        9              foot_pain_N     0.044076
#   10   -0.028138    5       10               ACL_tear_N     0.045527
#   11   -0.026504    5       11               ACL_tear_N     0.047292
#   12    0.737430   15       12               backache_N     0.047693
#   13   -1.469695    2       13              foot_pain_N     0.052655
#   14   -0.021289   10       14              cold_sore_N     0.056103
#   15   -0.028245   12       15            quad_injury_N     0.059402
#   16   -0.021274   20       16        annual_physical_N     0.062133
#   17    0.000594   13       17              hay_fever_N     0.063954
#   18   -0.048351    6       18                 myopia_N     0.065195
#   19    0.006748    3       19           ingrown_nail_N     0.065513},
#  'U8TID8118F': {'label': tensor([1]),
#   'pred': 0.3261567494177985,
#   'imp':     lrp_scores  idx  seq_idx                    token  att_weights
#   0    -0.036271    6        0                 myopia_N     0.032830
#   1    -0.015903   22        1           ankle_sprain_N     0.036142
#   2     0.013705    3        2           ingrown_nail_N     0.038933
#   3     1.033894    8        3               eye_exam_N     0.041079
#   4    -0.003690    9        4         peanut_allergy_N     0.041556
#   5     1.203183    8        5               eye_exam_N     0.042080
#   6    -0.061023    6        6                 myopia_N     0.041824
#   7     0.018531    3        7           ingrown_nail_N     0.041549
#   8    -0.022594   22        8           ankle_sprain_N     0.041171
#   9    -1.945589    2        9              foot_pain_N     0.039936
#   10   -0.037006    5       10               ACL_tear_N     0.039476
#   11   -0.019879   22       11           ankle_sprain_N     0.038977
#   12   -1.978225    7       12               headache_N     0.037741
#   13   -2.200327   43       13          beta_blockers_U     0.035622
#   14   -0.084784    6       14                 myopia_N     0.034357
#   15   -0.084474    6       15                 myopia_N     0.034317
#   16   -0.036519    5       16               ACL_tear_N     0.034008
#   17   -0.032564   20       17        annual_physical_N     0.032517
#   18   -0.031539   20       18        annual_physical_N     0.032201
#   19   -0.036297   18       19  electrolyte_imbalance_H     0.032159
#   20    0.013070    3       20           ingrown_nail_N     0.032360
#   21   -0.028403   20       21        annual_physical_N     0.033603
#   22   -0.080473    6       22                 myopia_N     0.034312
#   23    0.896050   15       23               backache_N     0.036036
#   24    1.506249   14       24             cut_finger_N     0.037428
#   25    1.309049    8       25               eye_exam_N     0.038671
#   26    1.214864    8       26               eye_exam_N     0.039115},
#  'CQDEHH7L81': {'label': tensor([1]),
#   'pred': -1.2561649534277852,
#   'imp':     lrp_scores  idx  seq_idx                    token  att_weights
#   0     0.011481    3        0           ingrown_nail_N     0.020601
#   1    -0.024109    5        1               ACL_tear_N     0.028064
#   2    -1.159734    7        2               headache_N     0.037476
#   3    -0.050946    6        3                 myopia_N     0.039176
#   4    -0.003701    9        4         peanut_allergy_N     0.036523
#   5    -1.404724    7        5               headache_N     0.036866
#   6    -0.032012    5        6               ACL_tear_N     0.040123
#   7    -0.021196   22        7           ankle_sprain_N     0.034532
#   8    -1.585680    2        8              foot_pain_N     0.032630
#   9    -0.032632    5        9               ACL_tear_N     0.029319
#   10   -1.603821   41       10          cardiac_rehab_U     0.027707
#   11    1.467029    8       11               eye_exam_N     0.028846
#   12   -0.013939   22       12           ankle_sprain_N     0.028691
#   13    1.525199   14       13             cut_finger_N     0.034100
#   14    1.161739   34       14    heart_valve_failure_A     0.035738
#   15    0.703937   45       15  sleep_apnea_treatment_U     0.041958
#   16    1.375639    8       16               eye_exam_N     0.042680
#   17   -1.633126    2       17              foot_pain_N     0.050061
#   18    0.766656   15       18               backache_N     0.055958
#   19    1.388011   14       19             cut_finger_N     0.054063
#   20   -0.001152   22       20           ankle_sprain_N     0.056306
#   21   -1.306150    2       21              foot_pain_N     0.065670
#   22   -1.186648    2       22              foot_pain_N     0.070953
#   23   -0.014551    9       23         peanut_allergy_N     0.071961},
#  'WDTNOKNDPO': {'label': tensor([1]),
#   'pred': 1.9756667332607385,
#   'imp':     lrp_scores  idx  seq_idx                        token  att_weights
#   0    -0.691216    7        0                   headache_N     0.010366
#   1    -0.028908    6        1                     myopia_N     0.012999
#   2     0.641614    8        2                   eye_exam_N     0.017170
#   3    -0.003854    9        3             peanut_allergy_N     0.022461
#   4    -0.006506   17        4                dental_exam_N     0.030530
#   5     0.660269    8        5                   eye_exam_N     0.040505
#   6     0.404463   23        6  Brain_Natriuretic_Peptide_H     0.049756
#   7    -0.003398   22        7               ankle_sprain_N     0.055086
#   8     0.458309   15        8                   backache_N     0.058480
#   9    -0.005268   17        9                dental_exam_N     0.057110
#   10   -1.057547    2       10                  foot_pain_N     0.056224
#   11    0.008764    3       11               ingrown_nail_N     0.059273
#   12    0.010323   21       12       ventricular_aneurysm_A     0.061287
#   13    0.863465   14       13                 cut_finger_N     0.064311
#   14   -0.001526   17       14                dental_exam_N     0.067107
#   15    0.761458    8       15                   eye_exam_N     0.068825
#   16   -0.014942    9       16             peanut_allergy_N     0.068130
#   17   -0.863689    2       17                  foot_pain_N     0.068059
#   18    0.685115   14       18                 cut_finger_N     0.068912
#   19   -0.008055   20       19            annual_physical_N     0.063408},
#  'K85BG2W4UL': {'label': tensor([1]),
#   'pred': -0.9319729830279808,
#   'imp':     lrp_scores  idx  seq_idx                        token  att_weights
#   0    -0.013918   22        0               ankle_sprain_N     0.032195
#   1    -0.030204    6        1                     myopia_N     0.031671
#   2     0.831098    8        2                   eye_exam_N     0.030568
#   3    -1.108037    2        3                  foot_pain_N     0.033087
#   4    -0.004000   10        4                  cold_sore_N     0.034912
#   5    -1.204035    2        5                  foot_pain_N     0.039418
#   6     0.623327   23        6  Brain_Natriuretic_Peptide_H     0.038500
#   7     1.145589    8        7                   eye_exam_N     0.043307
#   8    -1.386385    2        8                  foot_pain_N     0.051807
#   9     1.220399    8        9                   eye_exam_N     0.048026
#   10   -1.514115   39       10                        ARB_U     0.058004
#   11   -1.425876    2       11                  foot_pain_N     0.059180
#   12    1.210294    8       12                   eye_exam_N     0.060172
#   13   -0.011291    9       13             peanut_allergy_N     0.070952
#   14   -0.056862    6       14                     myopia_N     0.073672
#   15    0.011319    3       15               ingrown_nail_N     0.079397
#   16   -0.001214   13       16                  hay_fever_N     0.073352
#   17    0.559994   15       17                   backache_N     0.071895
#   18   -0.012204   13       18                  hay_fever_N     0.069883},
#  '1GDD553507': {'label': tensor([0]),
#   'pred': 1.3718036389688288,
#   'imp':    lrp_scores  idx  seq_idx             token  att_weights
#   0   -0.010436   17        0     dental_exam_N     0.040248
#   1   -0.002186    9        1  peanut_allergy_N     0.057977
#   2    0.434938   15        2        backache_N     0.075820
#   3    0.895319   46        3       pacemaker_U     0.110317
#   4    0.010408   13        4       hay_fever_N     0.146074
#   5   -0.960959   41        5   cardiac_rehab_U     0.161344
#   6    0.765471   14        6      cut_finger_N     0.197938
#   7   -0.017471   10        7       cold_sore_N     0.210282},
#  'X2PYHQOAPL': {'label': tensor([1]),
#   'pred': 0.8253880845931059,
#   'imp':     lrp_scores  idx  seq_idx                    token  att_weights
#   0     0.976067    8        0               eye_exam_N     0.063146
#   1    -1.312191    7        1               headache_N     0.061206
#   2    -0.031485   12        2            quad_injury_N     0.066259
#   3    -0.031152   12        3            quad_injury_N     0.069718
#   4     0.023834   13        4              hay_fever_N     0.074108
#   5     0.648833   40        5      catheter_ablation_U     0.088135
#   6    -0.020343   20        6        annual_physical_N     0.097298
#   7    -0.052525    6        7                 myopia_N     0.105965
#   8     0.510503   45        8  sleep_apnea_treatment_U     0.120076
#   9    -0.015853   20        9        annual_physical_N     0.122039
#   10    0.004655   22       10           ankle_sprain_N     0.132050},
#  '91S1IH3PSP': {'label': tensor([1]),
#   'pred': 1.4978247833901812,
#   'imp':     lrp_scores  idx  seq_idx                    token  att_weights
#   0    -0.036643    6        0                 myopia_N     0.019507
#   1    -0.022595    5        1               ACL_tear_N     0.022947
#   2    -0.027335   12        2            quad_injury_N     0.025552
#   3    -0.047975    6        3                 myopia_N     0.028233
#   4     0.595424   15        4               backache_N     0.033988
#   5    -0.016210   10        5              cold_sore_N     0.038312
#   6     0.621591   15        6               backache_N     0.043072
#   7    -0.026310   18        7  electrolyte_imbalance_H     0.047238
#   8     0.013531   13        8              hay_fever_N     0.051635
#   9     0.840690   32        9            alchoholism_H     0.059151
#   10   -0.018709   20       10        annual_physical_N     0.062418
#   11   -0.021268   10       11              cold_sore_N     0.064742
#   12   -1.232420   29       12     pulmonary_embolism_A     0.064520
#   13   -0.020099    5       13               ACL_tear_N     0.067031
#   14   -0.053119    6       14                 myopia_N     0.070724
#   15   -0.016346    5       15               ACL_tear_N     0.073065
#   16   -0.019586   12       16            quad_injury_N     0.074279
#   17    0.940527   14       17             cut_finger_N     0.077415
#   18   -0.014344   13       18              hay_fever_N     0.076170},
#  'MQUN99Y3AB': {'label': tensor([0]),
#   'pred': -1.8903919018609936,
#   'imp':     lrp_scores  idx  seq_idx                                 token  \
#   0     0.313256   14        0                          cut_finger_N
#   1     0.018655   13        1                           hay_fever_N
#   2    -0.474027    7        2                            headache_N
#   3     0.498480   42        3  Percutaneous_Coronary_Intervention_U
#   4     0.290619   15        4                            backache_N
#   5    -0.706804   39        5                                 ARB_U
#   6    -0.635228    7        6                            headache_N
#   7     0.009154    3        7                        ingrown_nail_N
#   8    -0.010155   20        8                     annual_physical_N
#   9     0.443548   32        9                         alchoholism_H
#   10   -0.003024    9       10                      peanut_allergy_N
#   11   -0.705268    2       11                           foot_pain_N
#   12   -0.027347    6       12                              myopia_N
#   13    0.008460    3       13                        ingrown_nail_N
#   14    0.339383   15       14                            backache_N
#   15    0.341368   15       15                            backache_N
#   16   -0.008305   22       16                        ankle_sprain_N
#   17    0.020073   13       17                           hay_fever_N
#   18   -0.693861    2       18                           foot_pain_N
#   19   -0.014897   12       19                         quad_injury_N
#   20   -0.007003   22       20                        ankle_sprain_N
#   21   -0.011222    5       21                            ACL_tear_N
#   22    0.006560    3       22                        ingrown_nail_N
#   23    0.012599   13       23                           hay_fever_N
#   24   -0.004701   17       24                         dental_exam_N
#   25   -0.469684    7       25                            headache_N
#   26   -0.433926    7       26                            headache_N
#   27   -0.009999   12       27                         quad_injury_N
#   28   -0.002276   13       28                           hay_fever_N
#
#       att_weights
#   0      0.009815
#   1      0.012092
#   2      0.017639
#   3      0.019119
#   4      0.018965
#   5      0.022770
#   6      0.029429
#   7      0.033936
#   8      0.037244
#   9      0.036998
#   10     0.038595
#   11     0.040342
#   12     0.040070
#   13     0.039107
#   14     0.037577
#   15     0.036933
#   16     0.037237
#   17     0.038006
#   18     0.039769
#   19     0.039239
#   20     0.041143
#   21     0.042121
#   22     0.043344
#   23     0.042116
#   24     0.038443
#   25     0.039764
#   26     0.045087
#   27     0.043128
#   28     0.039970  },
#  'KYR9MNY3KH': {'label': tensor([1]),
#   'pred': -0.33361922859296317,
#   'imp':     lrp_scores  idx  seq_idx                 token  att_weights
#   0    -0.736616    2        0           foot_pain_N     0.042416
#   1     0.000385    9        1      peanut_allergy_N     0.041605
#   2     0.654528   36        2  metabolic_disorder_H     0.040967
#   3    -0.022308    5        3            ACL_tear_N     0.040078
#   4     0.541478   15        4            backache_N     0.039376
#   5    -1.228300    2        5           foot_pain_N     0.036670
#   6    -0.002956    9        6      peanut_allergy_N     0.037935
#   7    -0.028600   12        7         quad_injury_N     0.037319
#   8    -1.219597   29        8  pulmonary_embolism_A     0.035680
#   9    -0.012710   10        9           cold_sore_N     0.033819
#   10   -0.030307   12       10         quad_injury_N     0.033961
#   11   -0.013226   17       11         dental_exam_N     0.034755
#   12    0.013616    3       12        ingrown_nail_N     0.035847
#   13    1.186258   14       13          cut_finger_N     0.037778
#   14    0.634227   15       14            backache_N     0.042625
#   15   -0.006542   17       15         dental_exam_N     0.044591
#   16   -1.239793    7       16            headache_N     0.046448
#   17    1.101652   14       17          cut_finger_N     0.052408
#   18   -0.003824   17       18         dental_exam_N     0.052135
#   19   -0.018904   12       19         quad_injury_N     0.054450
#   20   -0.015346   20       20     annual_physical_N     0.054635
#   21   -0.001348   17       21         dental_exam_N     0.059031
#   22   -0.000345   17       22         dental_exam_N     0.065472},
#  'P8G4OW3M52': {'label': tensor([0]),
#   'pred': 1.7475604919073897,
#   'imp':     lrp_scores  idx  seq_idx                                 token  \
#   0     0.407538   14        0                          cut_finger_N
#   1    -0.004082   10        1                           cold_sore_N
#   2    -0.006245   10        2                           cold_sore_N
#   3    -0.003052    9        3                      peanut_allergy_N
#   4    -0.003834    9        4                      peanut_allergy_N
#   5     0.620379   42        5  Percutaneous_Coronary_Intervention_U
#   6     0.706288   28        6                      cardiomyopathy_A
#   7    -0.033821    6        7                              myopia_N
#   8     0.718601    8        8                            eye_exam_N
#   9    -0.884000   41        9                       cardiac_rehab_U
#   10   -0.035701    6       10                              myopia_N
#   11    0.754494   14       11                          cut_finger_N
#   12   -0.761045    7       12                            headache_N
#   13   -0.009790    9       13                      peanut_allergy_N
#   14   -0.001093   17       14                         dental_exam_N
#
#       att_weights
#   0      0.020507
#   1      0.027464
#   2      0.032399
#   3      0.044334
#   4      0.052191
#   5      0.055028
#   6      0.065302
#   7      0.070044
#   8      0.080396
#   9      0.087838
#   10     0.091533
#   11     0.095492
#   12     0.092875
#   13     0.091664
#   14     0.092933  },
#  '8C2DJQFFGU': {'label': tensor([0]),
#   'pred': 1.4651136579577144,
#   'imp':     lrp_scores  idx  seq_idx                                 token  \
#   0     0.362478    8        0                            eye_exam_N
#   1     0.249811   15        1                            backache_N
#   2     0.007148    3        2                        ingrown_nail_N
#   3    -0.002018    9        3                      peanut_allergy_N
#   4    -0.007243   17        4                         dental_exam_N
#   5     0.354327   37        5                           diuretics_U
#   6     0.705304    8        6                            eye_exam_N
#   7    -0.009139   10        7                           cold_sore_N
#   8    -0.009294   17        8                         dental_exam_N
#   9    -0.010151   22        9                        ankle_sprain_N
#   10   -0.022656   12       10                         quad_injury_N
#   11   -1.125849    7       11                            headache_N
#   12   -1.117672    7       12                            headache_N
#   13    0.993434   14       13                          cut_finger_N
#   14    0.519467   15       14                            backache_N
#   15   -0.015260   20       15                     annual_physical_N
#   16    0.931955   42       16  Percutaneous_Coronary_Intervention_U
#   17   -0.004958   17       17                         dental_exam_N
#   18    0.012427   19       18             ventricular_hypertrophy_A
#   19   -0.042218    6       19                              myopia_N
#   20   -0.014304    5       20                            ACL_tear_N
#   21   -0.010812    9       21                      peanut_allergy_N
#   22   -0.040039    6       22                              myopia_N
#   23   -0.002079   22       23                        ankle_sprain_N
#   24    0.445881   15       24                            backache_N
#   25   -0.819000    7       25                            headache_N
#   26   -0.013100   20       26                     annual_physical_N
#   27   -0.011687   20       27                     annual_physical_N
#   28    0.004321    3       28                        ingrown_nail_N
#
#       att_weights
#   0      0.017795
#   1      0.021005
#   2      0.023334
#   3      0.023934
#   4      0.026873
#   5      0.028985
#   6      0.030634
#   7      0.031261
#   8      0.031771
#   9      0.032284
#   10     0.033030
#   11     0.033010
#   12     0.033902
#   13     0.036588
#   14     0.039702
#   15     0.042556
#   16     0.040506
#   17     0.037499
#   18     0.037110
#   19     0.036984
#   20     0.037047
#   21     0.037407
#   22     0.039407
#   23     0.041013
#   24     0.042005
#   25     0.040810
#   26     0.040518
#   27     0.041081
#   28     0.041950  },
#  'QFIS78CCHQ': {'label': tensor([0]),
#   'pred': -1.0862154047543977,
#   'imp':     lrp_scores  idx  seq_idx              token  att_weights
#   0     0.325390   15        0         backache_N     0.022465
#   1    -0.770696    7        1         headache_N     0.028890
#   2    -0.018379    5        2         ACL_tear_N     0.031579
#   3     0.765641    8        3         eye_exam_N     0.029556
#   4    -0.010927   17        4      dental_exam_N     0.031996
#   5    -0.003105    9        5   peanut_allergy_N     0.036084
#   6    -0.040227    6        6           myopia_N     0.036656
#   7    -0.010837   17        7      dental_exam_N     0.037441
#   8     0.535688   15        8         backache_N     0.035388
#   9    -0.016078   20        9  annual_physical_N     0.039201
#   10   -0.012596   22       10     ankle_sprain_N     0.039161
#   11   -1.145330    7       11         headache_N     0.047759
#   12    0.577459   15       12         backache_N     0.047042
#   13   -1.121824    7       13         headache_N     0.053328
#   14    0.991631    8       14         eye_exam_N     0.049674
#   15   -0.016677   20       15  annual_physical_N     0.050391
#   16   -0.016728   20       16  annual_physical_N     0.050617
#   17   -1.145282   43       17    beta_blockers_U     0.055927
#   18   -0.043921    6       18           myopia_N     0.056809
#   19    0.820055   31       19            edema_H     0.051066
#   20   -0.004915   17       20      dental_exam_N     0.052253
#   21   -0.856804    2       21        foot_pain_N     0.059776
#   22   -0.002909   17       22      dental_exam_N     0.056939},
#  'T09QKGXQQY': {'label': tensor([1]),
#   'pred': -1.01038657594766,
#   'imp':     lrp_scores  idx  seq_idx              token  att_weights
#   0    -0.019666    6        0           myopia_N     0.021457
#   1    -0.008664   20        1  annual_physical_N     0.020527
#   2    -0.010913   17        2      dental_exam_N     0.020631
#   3    -0.774095    7        3         headache_N     0.023569
#   4     0.413223   15        4         backache_N     0.024967
#   5    -0.013033   20        5  annual_physical_N     0.029238
#   6    -0.014613   22        6     ankle_sprain_N     0.032873
#   7    -0.002021    9        7   peanut_allergy_N     0.033433
#   8    -0.023878   12        8      quad_injury_N     0.033911
#   9    -0.024524   12        9      quad_injury_N     0.034177
#   10   -0.025153   12       10      quad_injury_N     0.033085
#   11   -0.012512   17       11      dental_exam_N     0.033563
#   12   -0.026261   12       12      quad_injury_N     0.034011
#   13   -0.018427   20       13  annual_physical_N     0.034517
#   14   -0.018879   20       14  annual_physical_N     0.035112
#   15   -0.011768   17       15      dental_exam_N     0.035762
#   16    0.593352   37       16        diuretics_U     0.035597
#   17   -0.052717    6       17           myopia_N     0.036453
#   18   -0.014977   10       18        cold_sore_N     0.037527
#   19   -0.019181    5       19         ACL_tear_N     0.038947
#   20   -1.309392    7       20         headache_N     0.043421
#   21   -1.359314    2       21        foot_pain_N     0.049332
#   22   -0.056174    6       22           myopia_N     0.051936
#   23    0.012962    3       23     ingrown_nail_N     0.059464
#   24    0.567395   30       24         troponin_H     0.058295
#   25    0.997684   14       25       cut_finger_N     0.055058
#   26    0.005484   22       26     ankle_sprain_N     0.053137},
#  'PVAW1IEYZF': {'label': tensor([1]),
#   'pred': 1.6480508419683844,
#   'imp':     lrp_scores  idx  seq_idx                       token  att_weights
#   0     0.018666    3        0              ingrown_nail_N     0.013767
#   1    -0.025703   22        1              ankle_sprain_N     0.016381
#   2    -0.027976   20        2           annual_physical_N     0.019376
#   3    -0.020407   22        3              ankle_sprain_N     0.022510
#   4    -0.016140   22        4              ankle_sprain_N     0.025545
#   5    -0.014600   22        5              ankle_sprain_N     0.029036
#   6     0.009034   21        6      ventricular_aneurysm_A     0.032575
#   7     1.784741   14        7                cut_finger_N     0.038631
#   8     0.027445   13        8                 hay_fever_N     0.041783
#   9     1.803012    8        9                  eye_exam_N     0.045210
#   10   -0.031020   20       10           annual_physical_N     0.045682
#   11    0.016126    4       11  congestive_heart_failure_A     0.045497
#   12    1.508874   27       12               sleep_apnea_H     0.043726
#   13   -2.719690    7       13                  headache_N     0.039101
#   14   -2.866861    2       14                 foot_pain_N     0.034874
#   15   -2.755923    7       15                  headache_N     0.032343
#   16   -0.045256   10       16                 cold_sore_N     0.031658
#   17   -0.006437   22       17              ankle_sprain_N     0.031049
#   18    0.020604    3       18              ingrown_nail_N     0.031683
#   19   -0.006184   13       19                 hay_fever_N     0.032097
#   20   -0.013892   13       20                 hay_fever_N     0.033892
#   21   -0.028124    5       21                  ACL_tear_N     0.035454
#   22    1.151649   15       22                  backache_N     0.039442
#   23   -0.028617   13       23                 hay_fever_N     0.043026
#   24    1.077527   15       24                  backache_N     0.047005
#   25    1.661181    8       25                  eye_exam_N     0.049676
#   26    1.565006    8       26                  eye_exam_N     0.050227
#   27   -0.015817   20       27           annual_physical_N     0.048755},
#  '87OPIHFEOL': {'label': tensor([0]),
#   'pred': -2.3444935206621134,
#   'imp':     lrp_scores  idx  seq_idx                                    token  \
#   0    -0.008354    5        0                               ACL_tear_N
#   1     0.360992    8        1                               eye_exam_N
#   2    -0.007159   17        2                            dental_exam_N
#   3    -0.484016   24        3  Chronic_Obstructive_Pulmonary_Disease_A
#   4    -0.544471   38        4               electrical_cardioversion_U
#   5    -0.008627   17        5                            dental_exam_N
#   6    -0.551538   44        6                         ACE_inhibitors_U
#   7     0.480664    8        7                               eye_exam_N
#   8     0.515346   14        8                             cut_finger_N
#   9    -0.007292   20        9                        annual_physical_N
#   10   -0.527911    2       10                              foot_pain_N
#   11   -0.009698    5       11                               ACL_tear_N
#   12   -0.445294    7       12                               headache_N
#   13    0.015335   13       13                              hay_fever_N
#   14   -0.376121    7       14                               headache_N
#   15   -0.356632    2       15                              foot_pain_N
#   16   -0.003487   22       16                           ankle_sprain_N
#   17   -0.013526    6       17                                 myopia_N
#   18   -0.005342   20       18                        annual_physical_N
#   19   -0.262788    7       19                               headache_N
#   20   -0.002824    9       20                         peanut_allergy_N
#   21   -0.004826   10       21                              cold_sore_N
#   22    0.000619   22       22                           ankle_sprain_N
#
#       att_weights
#   0      0.007834
#   1      0.011780
#   2      0.016815
#   3      0.025172
#   4      0.035400
#   5      0.042024
#   6      0.051590
#   7      0.051281
#   8      0.045647
#   9      0.042526
#   10     0.047284
#   11     0.044773
#   12     0.049559
#   13     0.046502
#   14     0.048182
#   15     0.053978
#   16     0.059508
#   17     0.057446
#   18     0.058234
#   19     0.057506
#   20     0.051924
#   21     0.047583
#   22     0.047451  },
#  'M5N2Q0ODI8': {'label': tensor([1]),
#   'pred': -0.891601165113254,
#   'imp':     lrp_scores  idx  seq_idx                        token  att_weights
#   0    -0.012716    5        0                   ACL_tear_N     0.027239
#   1    -0.009024   17        1                dental_exam_N     0.030079
#   2    -0.016915   12        2                quad_injury_N     0.030299
#   3    -0.002367   10        3                  cold_sore_N     0.028727
#   4     0.010430    3        4               ingrown_nail_N     0.028860
#   5     0.802273    8        5                   eye_exam_N     0.027545
#   6    -0.016204   22        6               ankle_sprain_N     0.027271
#   7    -1.136081    2        7                  foot_pain_N     0.028979
#   8    -0.027447   12        8                quad_injury_N     0.030005
#   9     0.015460    3        9               ingrown_nail_N     0.030479
#   10    0.628325   15       10                   backache_N     0.030604
#   11   -1.349534    2       11                  foot_pain_N     0.035029
#   12   -1.286027    7       12                   headache_N     0.042829
#   13   -0.055221    6       13                     myopia_N     0.048545
#   14    0.661063   23       14  Brain_Natriuretic_Peptide_H     0.047909
#   15    0.584364   45       15      sleep_apnea_treatment_U     0.049599
#   16    0.021906   13       16                  hay_fever_N     0.051748
#   17    0.012539    3       17               ingrown_nail_N     0.055305
#   18    0.011885    3       18               ingrown_nail_N     0.053301
#   19   -0.002315   22       19               ankle_sprain_N     0.049923
#   20   -0.050203    6       20                     myopia_N     0.050260
#   21    1.023211   14       21                 cut_finger_N     0.048189
#   22   -0.009227    5       22                   ACL_tear_N     0.047781
#   23   -0.924159    7       23                   headache_N     0.049801
#   24   -0.012460    5       24                   ACL_tear_N     0.049695},
#  'BCALILSWU6': {'label': tensor([1]),
#   'pred': 0.17891198229842076,
#   'imp':     lrp_scores  idx  seq_idx                      token  att_weights
#   0    -1.051977    7        0                 headache_N     0.042104
#   1    -0.048743    6        1                   myopia_N     0.035473
#   2    -1.357956    2        2                foot_pain_N     0.029726
#   3     0.733872   35        3               arrhythmia_A     0.027921
#   4    -0.024574   22        4             ankle_sprain_N     0.025522
#   5    -0.007175   10        5                cold_sore_N     0.024618
#   6     0.007420   19        6  ventricular_hypertrophy_A     0.024279
#   7    -0.037204   12        7              quad_injury_N     0.024161
#   8    -1.545539   25        8  coronary_artery_disease_H     0.023056
#   9     0.827235   15        9                 backache_N     0.023569
#   10   -0.016014   17       10              dental_exam_N     0.023941
#   11    1.545937   14       11               cut_finger_N     0.026201
#   12   -0.023183    5       12                 ACL_tear_N     0.026842
#   13   -0.010600   17       13              dental_exam_N     0.028593
#   14   -0.027055   10       14                cold_sore_N     0.030520
#   15   -0.003332   22       15             ankle_sprain_N     0.035443
#   16   -0.030753   10       16                cold_sore_N     0.039015
#   17   -0.029060   12       17              quad_injury_N     0.043330
#   18    0.002367   22       18             ankle_sprain_N     0.049150
#   19    1.253853    8       19                 eye_exam_N     0.060614
#   20   -0.012471    5       20                 ACL_tear_N     0.068185
#   21   -0.019228   12       21              quad_injury_N     0.085083
#   22    1.002196    8       22                 eye_exam_N     0.097724
#   23   -0.995524    7       23                 headache_N     0.104931},
#  '5H2FZA55XY': {'label': tensor([1]),
#   'pred': 1.311114837262966,
#   'imp':     lrp_scores  idx  seq_idx                                    token  \
#   0     0.022077    3        0                           ingrown_nail_N
#   1    -0.027564   17        1                            dental_exam_N
#   2     0.026971    3        2                           ingrown_nail_N
#   3     0.027433    3        3                           ingrown_nail_N
#   4    -2.479729    2        4                              foot_pain_N
#   5    -0.053200   12        5                            quad_injury_N
#   6    -0.013826   22        6                           ankle_sprain_N
#   7    -0.021731    9        7                         peanut_allergy_N
#   8    -0.033240    5        8                               ACL_tear_N
#   9    -0.030072    5        9                               ACL_tear_N
#   10    1.830031   14       10                             cut_finger_N
#   11   -0.012192   13       11                              hay_fever_N
#   12    1.568217    8       12                               eye_exam_N
#   13    0.880178   23       13              Brain_Natriuretic_Peptide_H
#   14    0.005738    3       14                           ingrown_nail_N
#   15    1.154973   36       15                     metabolic_disorder_H
#   16   -1.358435   24       16  Chronic_Obstructive_Pulmonary_Disease_A
#   17    0.005962   22       17                           ankle_sprain_N
#   18    0.006417    3       18                           ingrown_nail_N
#
#       att_weights
#   0      0.025230
#   1      0.026718
#   2      0.027239
#   3      0.030429
#   4      0.027468
#   5      0.028543
#   6      0.030285
#   7      0.031731
#   8      0.034268
#   9      0.037208
#   10     0.048715
#   11     0.059156
#   12     0.074607
#   13     0.084783
#   14     0.086520
#   15     0.089758
#   16     0.087059
#   17     0.086045
#   18     0.084238  },
#  'FSOQFE2GD9': {'label': tensor([0]),
#   'pred': -2.6123146058445834,
#   'imp':     lrp_scores  idx  seq_idx            token  att_weights
#   0    -0.424653    2        0      foot_pain_N     0.006559
#   1    -0.008304   17        1    dental_exam_N     0.015843
#   2    -0.478541    2        2      foot_pain_N     0.032610
#   3    -0.441992    7        3       headache_N     0.050055
#   4    -0.424932    7        4       headache_N     0.057704
#   5     0.486873   46        5      pacemaker_U     0.060588
#   6    -0.453182   43        6  beta_blockers_U     0.065081
#   7    -0.010313   12        7    quad_injury_N     0.065239
#   8    -0.002203   10        8      cold_sore_N     0.067350
#   9    -0.360250    2        9      foot_pain_N     0.067830
#   10   -0.004189   22       10   ankle_sprain_N     0.066788
#   11   -0.003598   22       11   ankle_sprain_N     0.068325
#   12   -0.310419    2       12      foot_pain_N     0.065080
#   13    0.286889    8       13       eye_exam_N     0.067142
#   14   -0.286319    2       14      foot_pain_N     0.068137
#   15   -0.012023    6       15         myopia_N     0.063867
#   16   -0.011814    6       16         myopia_N     0.056632
#   17    0.000561   22       17   ankle_sprain_N     0.055172},
#  'SQK6XG46LU': {'label': tensor([1]),
#   'pred': 1.4473155711935513,
#   'imp':     lrp_scores  idx  seq_idx                       token  att_weights
#   0     0.000421    9        0            peanut_allergy_N     0.022249
#   1     0.750990    8        1                  eye_exam_N     0.030087
#   2    -0.011497   17        2               dental_exam_N     0.034908
#   3    -0.018855    5        3                  ACL_tear_N     0.039652
#   4    -1.124559   41        4             cardiac_rehab_U     0.036274
#   5     0.914758    8        5                  eye_exam_N     0.044248
#   6     0.534761   15        6                  backache_N     0.051598
#   7    -0.045743    6        7                    myopia_N     0.057002
#   8     1.032205   14        8                cut_finger_N     0.067412
#   9    -0.016396   20        9           annual_physical_N     0.071360
#   10   -0.016879   20       10           annual_physical_N     0.075972
#   11   -0.049020    6       11                    myopia_N     0.081570
#   12   -1.146878   41       12             cardiac_rehab_U     0.074676
#   13    0.012088    4       13  congestive_heart_failure_A     0.074525
#   14   -0.016791   20       14           annual_physical_N     0.075611
#   15    0.467533   15       15                  backache_N     0.081318
#   16    0.003957   22       16              ankle_sprain_N     0.081537},
#  'J6WX7TV8RM': {'label': tensor([1]),
#   'pred': 2.1678220080264423,
# ...
#   21   -0.004747   10       21        cold_sore_N     0.056898},
#  'X4XCC9MXIR': {'label': tensor([1]),
#   'pred': -0.913782121402771,
#   'imp':     lrp_scores  idx  seq_idx                       token  att_weights
#   0    -0.024906    5        0                  ACL_tear_N     0.035265
#   1    -0.017833   20        1           annual_physical_N     0.032897
#   2     0.020993    3        2              ingrown_nail_N     0.033099
#   3    -1.647451    2        3                 foot_pain_N     0.036298
#   4    -1.709477   38        4  electrical_cardioversion_U     0.040120
#   5     0.072617   13        5                 hay_fever_N     0.042168
#   6    -0.031192   20        6           annual_physical_N     0.041599
#   7    -0.014030   10        7                 cold_sore_N     0.048827
#   8     0.013702   19        8   ventricular_hypertrophy_A     0.051808
#   9    -1.976733   44        9            ACE_inhibitors_U     0.057187
#   10    1.718321   14       10                cut_finger_N     0.060790
#   11   -0.029146   20       11           annual_physical_N     0.067255
#   12    0.015130   13       12                 hay_fever_N     0.082037
#   13    0.013042    3       13              ingrown_nail_N     0.093848
#   14    0.010568    3       14              ingrown_nail_N     0.095461
#   15    1.338266   14       15                cut_finger_N     0.093251
#   16    1.111474    8       16                  eye_exam_N     0.088089},
#  'MTSU40FBRM': {'label': tensor([0]),
#   'pred': 0.6774138359920413,
#   'imp':     lrp_scores  idx  seq_idx                       token  att_weights
#   0    -1.231317    2        0                 foot_pain_N     0.033612
#   1    -0.030296    5        1                  ACL_tear_N     0.031406
#   2    -0.024625   22        2              ankle_sprain_N     0.029217
#   3    -0.061017    6        3                    myopia_N     0.027725
#   4    -0.037043   12        4               quad_injury_N     0.026959
#   5    -0.021003   22        5              ankle_sprain_N     0.026795
#   6    -0.037395   12        6               quad_injury_N     0.027100
#   7    -0.009373    9        7            peanut_allergy_N     0.027726
#   8     0.849888   15        8                  backache_N     0.030435
#   9    -0.015226    9        9            peanut_allergy_N     0.032267
#   10   -1.850858   38       10  electrical_cardioversion_U     0.030326
#   11    1.212707   36       11        metabolic_disorder_H     0.034637
#   12    0.012532    3       12              ingrown_nail_N     0.037124
#   13   -0.069151    6       13                    myopia_N     0.040402
#   14    1.315882    8       14                  eye_exam_N     0.049680
#   15   -0.007036   13       15                 hay_fever_N     0.056970
#   16    1.335176   14       16                cut_finger_N     0.067852
#   17    0.004116   22       17              ankle_sprain_N     0.073440
#   18   -0.016093   20       18           annual_physical_N     0.077493
#   19   -0.025545   10       19                 cold_sore_N     0.080382
#   20   -1.076112    7       20                  headache_N     0.077779
#   21    0.484948   15       21                  backache_N     0.080673},
#  'EIMHT6722Z': {'label': tensor([1]),
#   'pred': 0.6124019967386051,
#   'imp':     lrp_scores  idx  seq_idx                                 token  \
#   0    -0.022301    5        0                            ACL_tear_N
#   1    -1.170995    7        1                            headache_N
#   2     1.055249    8        2                            eye_exam_N
#   3    -0.012645   17        3                         dental_exam_N
#   4    -0.028217   12        4                         quad_injury_N
#   5     0.600347   40        5                   catheter_ablation_U
#   6     1.102927   42        6  Percutaneous_Coronary_Intervention_U
#   7     0.009848    3        7                        ingrown_nail_N
#   8    -0.006465   17        8                         dental_exam_N
#   9    -0.048245    6        9                              myopia_N
#   10   -0.013189    5       10                            ACL_tear_N
#   11   -0.976806    2       11                           foot_pain_N
#   12   -0.012417    9       12                      peanut_allergy_N
#
#       att_weights
#   0      0.058926
#   1      0.053138
#   2      0.056786
#   3      0.058778
#   4      0.061625
#   5      0.068138
#   6      0.079731
#   7      0.087868
#   8      0.093179
#   9      0.096755
#   10     0.101816
#   11     0.093589
#   12     0.089671  },
#  '4FS6YKZFAE': {'label': tensor([1]),
#   'pred': -0.2039766851732888,
#   'imp':     lrp_scores  idx  seq_idx                        token  att_weights
#   0     0.000189    9        0             peanut_allergy_N     0.034371
#   1    -0.013815   17        1                dental_exam_N     0.035822
#   2     0.039841   13        2                  hay_fever_N     0.036579
#   3    -0.007432   10        3                  cold_sore_N     0.037094
#   4     0.597681   23        4  Brain_Natriuretic_Peptide_H     0.036391
#   5    -0.018962   20        5            annual_physical_N     0.036239
#   6    -0.013784   22        6               ankle_sprain_N     0.036392
#   7    -0.033761   18        7      electrolyte_imbalance_H     0.036157
#   8    -1.408464    2        8                  foot_pain_N     0.038849
#   9     0.677411   26        9               hypertension_A     0.038270
#   10    1.153124    8       10                   eye_exam_N     0.036298
#   11   -0.016867   10       11                  cold_sore_N     0.035601
#   12   -0.009428   22       12               ankle_sprain_N     0.035082
#   13   -0.028345   12       13                quad_injury_N     0.034754
#   14   -0.055643    6       14                     myopia_N     0.034625
#   15    0.013454    3       15               ingrown_nail_N     0.034558
#   16   -0.009951   17       16                dental_exam_N     0.034523
#   17   -0.021288    5       17                   ACL_tear_N     0.034951
#   18   -0.018187   10       18                  cold_sore_N     0.035694
#   19    0.012459    3       19               ingrown_nail_N     0.035952
#   20   -1.216109    7       20                   headache_N     0.038990
#   21    0.594334   15       21                   backache_N     0.039037
#   22   -0.006406   17       22                dental_exam_N     0.039702
#   23    0.542828   15       23                   backache_N     0.039136
#   24   -0.003832   17       24                dental_exam_N     0.039320
#   25   -0.931375    2       25                  foot_pain_N     0.042330
#   26   -0.014753   20       26            annual_physical_N     0.043283},
#  '9GD3PENMAC': {'label': tensor([1]),
#   'pred': 1.8633113441324336,
#   'imp':     lrp_scores  idx  seq_idx                                 token  \
#   0    -0.009086   20        0                     annual_physical_N
#   1    -0.004318   10        1                           cold_sore_N
#   2    -0.014838    5        2                            ACL_tear_N
#   3     0.008693    3        3                        ingrown_nail_N
#   4     0.006224   19        4             ventricular_hypertrophy_A
#   5    -0.006355   17        5                         dental_exam_N
#   6     0.745088   42        6  Percutaneous_Coronary_Intervention_U
#   7    -0.003076   22        7                        ankle_sprain_N
#   8     0.756270    8        8                            eye_exam_N
#   9    -1.027791   44        9                      ACE_inhibitors_U
#   10   -0.004887   17       10                         dental_exam_N
#   11    0.764868    8       11                            eye_exam_N
#   12    0.772604    8       12                            eye_exam_N
#   13   -0.011940   20       13                     annual_physical_N
#   14    0.003400   13       14                           hay_fever_N
#   15   -0.012647   20       15                     annual_physical_N
#   16   -0.944958    2       16                           foot_pain_N
#   17   -0.014363   20       17                     annual_physical_N
#   18    0.750850   14       18                          cut_finger_N
#   19   -0.010024   20       19                     annual_physical_N
#   20   -0.006994    5       20                            ACL_tear_N
#   21   -0.011742    9       21                      peanut_allergy_N
#
#       att_weights
#   0      0.013105
#   1      0.015957
#   2      0.019558
#   3      0.025430
#   4      0.030583
#   5      0.033131
#   6      0.038941
#   7      0.042559
#   8      0.046092
#   9      0.049075
#   10     0.053691
#   11     0.056767
#   12     0.055002
#   13     0.055963
#   14     0.056645
#   15     0.058454
#   16     0.058011
#   17     0.058096
#   18     0.059731
#   19     0.059132
#   20     0.057941
#   21     0.056135  },
#  'ZP9KF61ECV': {'label': tensor([0]),
#   'pred': -1.966765275267775,
#   'imp':     lrp_scores  idx  seq_idx                  token  att_weights
#   0     0.601748   14        0           cut_finger_N     0.010659
#   1    -0.775862    7        1             headache_N     0.019386
#   2     0.000336    9        2       peanut_allergy_N     0.035257
#   3     0.663202   34        3  heart_valve_failure_A     0.043132
#   4    -0.038179    6        4               myopia_N     0.055631
#   5    -1.012712   44        5       ACE_inhibitors_U     0.086620
#   6    -0.939930   43        6        beta_blockers_U     0.117569
#   7     0.023381   13        7            hay_fever_N     0.118617
#   8    -0.017952   12        8          quad_injury_N     0.116295
#   9    -0.741705    2        9            foot_pain_N     0.136172
#   10    0.008067    3       10         ingrown_nail_N     0.143523
#   11    0.308665   15       11             backache_N     0.117139},
#  'B5S2CIXZJ3': {'label': tensor([1]),
#   'pred': -0.8717543312165977,
#   'imp':     lrp_scores  idx  seq_idx                       token  att_weights
#   0     0.748184    8        0                  eye_exam_N     0.024684
#   1     0.526300   15        1                  backache_N     0.024332
#   2    -0.001929    9        2            peanut_allergy_N     0.024930
#   3    -1.475329   38        3  electrical_cardioversion_U     0.028966
#   4     0.046741   13        4                 hay_fever_N     0.031255
#   5    -0.013627   10        5                 cold_sore_N     0.032450
#   6    -1.451797    7        6                  headache_N     0.039315
#   7     1.353304   14        7                cut_finger_N     0.036811
#   8     1.365475   14        8                cut_finger_N     0.031972
#   9    -0.011560   17        9               dental_exam_N     0.030293
#   10   -1.587788    2       10                 foot_pain_N     0.032465
#   11    1.128600   33       11       elevated_creatinine_H     0.028841
#   12   -0.030805   12       12               quad_injury_N     0.027418
#   13   -0.024273   10       13                 cold_sore_N     0.025806
#   14    0.013387    3       14              ingrown_nail_N     0.024567
#   15   -0.015128    9       15            peanut_allergy_N     0.023283
#   16    1.238411    8       16                  eye_exam_N     0.020869
#   17   -0.019376   20       17           annual_physical_N     0.019836
#   18    1.192990    8       18                  eye_exam_N     0.018555
#   19   -0.008009   17       19               dental_exam_N     0.018641
#   20   -1.343191   44       20            ACE_inhibitors_U     0.020333
#   21   -0.014431   10       21                 cold_sore_N     0.022286
#   22   -1.043036    7       22                  headache_N     0.028415
#   23   -0.007085   22       23              ankle_sprain_N     0.035980
#   24    0.013107   13       24                 hay_fever_N     0.043006
#   25   -0.788800    7       25                  headache_N     0.054061
#   26   -0.002964   22       26              ankle_sprain_N     0.060155
#   27    0.007387    3       27              ingrown_nail_N     0.062373
#   28   -0.008072    9       28            peanut_allergy_N     0.062766
#   29   -0.503934    7       29                  headache_N     0.065334},
#  'JAM768VYC5': {'label': tensor([1]),
#   'pred': -1.943571486903516,
#   'imp':     lrp_scores  idx  seq_idx             token  att_weights
#   0    -0.013818   12        0     quad_injury_N     0.013500
#   1    -0.001021   10        1       cold_sore_N     0.026414
#   2    -0.000683    9        2  peanut_allergy_N     0.039271
#   3    -0.010380   17        3     dental_exam_N     0.055828
#   4    -0.766370    7        4        headache_N     0.078281
#   5     0.371076   30        5        troponin_H     0.074996
#   6     0.389369   35        6      arrhythmia_A     0.069821
#   7    -0.004205    9        7  peanut_allergy_N     0.074052
#   8    -0.697872    2        8       foot_pain_N     0.099147
#   9    -0.614218    2        9       foot_pain_N     0.111050
#   10   -0.002640   22       10    ankle_sprain_N     0.113264
#   11   -0.492001    2       11       foot_pain_N     0.123753
#   12   -0.010536   10       12       cold_sore_N     0.120622},
#  'M158HNY2IS': {'label': tensor([0]),
#   'pred': 2.027030091750139,
#   'imp':     lrp_scores  idx  seq_idx                token  att_weights
#   0     0.011369   13        0          hay_fever_N     0.014217
#   1     0.288518    8        1           eye_exam_N     0.026010
#   2    -0.001045    9        2     peanut_allergy_N     0.042530
#   3     0.383022   46        3          pacemaker_U     0.057050
#   4     0.412722   14        4         cut_finger_N     0.060627
#   5     0.004550    3        5       ingrown_nail_N     0.065314
#   6     0.280316   40        6  catheter_ablation_U     0.074600
#   7     0.523220    8        7           eye_exam_N     0.082358
#   8    -0.028717    6        8             myopia_N     0.085013
#   9    -0.690627    7        9           headache_N     0.089557
#   10   -0.000467   22       10       ankle_sprain_N     0.096878
#   11    0.530500    8       11           eye_exam_N     0.101471
#   12    0.001917   22       12       ankle_sprain_N     0.102758
#   13   -0.008940    9       13     peanut_allergy_N     0.101616},
#  'MXF00HFI5C': {'label': tensor([1]),
#   'pred': 2.033644206317783,
#   'imp':     lrp_scores  idx  seq_idx                          token  att_weights
#   0    -0.016453    6        0                       myopia_N     0.011276
#   1     0.432393    8        1                     eye_exam_N     0.015951
#   2    -0.011032    5        2                     ACL_tear_N     0.020316
#   3     0.016652   13        3                    hay_fever_N     0.025125
#   4    -0.702957    2        4                    foot_pain_N     0.027937
#   5     0.423855   32        5                  alchoholism_H     0.033156
#   6    -0.017008   11        6  Acute_Myocardial_Infarction_A     0.037127
#   7     0.005948   13        7                    hay_fever_N     0.040593
#   8    -0.007229    9        8               peanut_allergy_N     0.045475
#   9     0.518146   33        9          elevated_creatinine_H     0.048425
#   10    0.000850   13       10                    hay_fever_N     0.051735
#   11   -0.013931   12       11                  quad_injury_N     0.053446
#   12    0.634222    8       12                     eye_exam_N     0.054436
#   13   -0.012988   12       13                  quad_injury_N     0.055778
#   14    0.707753   14       14                   cut_finger_N     0.056648
#   15   -0.011293    9       15               peanut_allergy_N     0.055880
#   16   -0.012313   12       16                  quad_injury_N     0.055124
#   17   -0.014463   10       17                    cold_sore_N     0.055318
#   18   -0.010975    9       18               peanut_allergy_N     0.053282
#   19    0.004454    3       19                 ingrown_nail_N     0.051362
#   20   -0.005772   13       20                    hay_fever_N     0.050761
#   21   -0.013535   10       21                    cold_sore_N     0.050925
#   22   -0.012581   10       22                    cold_sore_N     0.049924},
#  ...}

# %%
print(f"LRP: {len(lrp_results[best_epoch])}")
print(f"SHAP: {len(shap_results[best_epoch])}")
assert len(lrp_results[best_epoch]) == len(shap_results[best_epoch])
# Out:
# LRP: 7000
# SHAP: 7000

# %% [markdown]
# ## Merge LRP and SHAP scores

# %%
for pid in lrp_results[best_epoch].keys():
    orig_len = lrp_results[best_epoch][pid]["imp"].shape[0]
    lrp_results[best_epoch][pid]["imp"] = lrp_results[best_epoch][pid]["imp"].merge(
        shap_results[best_epoch][pid]["imp"], on=["seq_idx", "token"]
    )
    assert orig_len == lrp_results[best_epoch][pid]["imp"].shape[0]
    lrp_results[best_epoch][pid]["imp"] = lrp_results[best_epoch][pid]["imp"][
        ["idx", "seq_idx", "token", "att_weights", "lrp_scores", "shap_scores"]
    ]

# %%
test_results = lrp_results

# %% [markdown]
# ## Calculate similarity scores

# %%
import sys
import rbo
from scipy import stats
import numpy as np

def get_wtau(x, y):
    return stats.weightedtau(x, y, rank=None)[0]


def get_rbo(x, y, uid, p=0.7):
    x_idx = np.argsort(x)[::-1]
    y_idx = np.argsort(y)[::-1]

    return rbo.RankingSimilarity(
        [uid[idx] for idx in x_idx], [uid[idx] for idx in y_idx]
    ).rbo(p=p)


# calculate ground truth scores
def is_value(x):
    if "_N" in x:
        return False
    return True

# %%
# calculate similarity indexes for test
epoch_test_lrp_shap_t_corr = []
epoch_test_lrp_shap_rbo = []
epoch_test_lrp_sim = []
epoch_test_shap_sim = []

rbo_p = 0.95

# %%
for pid in test_results[best_epoch].keys():
    imp_df = test_results[best_epoch][pid]["imp"]
    imp_df["u_token"] = [
        str(seq) + "_" + str(token)
        for seq, token in zip(imp_df["seq_idx"], imp_df["token"])
    ]
    test_results[best_epoch][pid]["lrp_shap_t_corr"] = get_wtau(
        imp_df["lrp_scores"], imp_df["shap_scores"]
    )

    test_results[best_epoch][pid]["lrp_shap_rbo"] = get_rbo(
        imp_df["lrp_scores"],
        imp_df["shap_scores"],
        imp_df["u_token"].tolist(),
        p=rbo_p,
    )

    # gt similarity
    gt_idx = [x for x, tok in enumerate(imp_df.u_token) if is_value(tok)]
    n_gt = len(gt_idx)
    if n_gt > 0:
        lrp_idx = np.argsort(np.abs(imp_df.lrp_scores.values))[::-1][:n_gt]
        shap_idx = np.argsort(np.abs(imp_df.shap_scores.values))[::-1][:n_gt]
        att_idx = np.argsort(np.abs(imp_df.att_weights.values))[::-1][:n_gt]
        lrp_sim = len(set(lrp_idx).intersection(gt_idx)) / n_gt
        shap_sim = len(set(shap_idx).intersection(gt_idx)) / n_gt
        att_sim = len(set(att_idx).intersection(gt_idx)) / n_gt
    else:
        print(f"-1 is the output for {pid}")
        lrp_sim = -1
        shap_sim = -1
    test_results[best_epoch][pid]["lrp_sim"] = lrp_sim
    test_results[best_epoch][pid]["shap_sim"] = shap_sim
    test_results[best_epoch][pid]["att_sim"] = att_sim

# %%
test_results[best_epoch][pid]['imp'].head()
# Out:
#    idx  seq_idx          token  att_weights  lrp_scores  shap_scores  \
# 0    6        0       myopia_N     0.009735   -0.010823    -0.012647
# 1   12        1  quad_injury_N     0.012768   -0.008046    -0.008752
# 2    8        2     eye_exam_N     0.017213    0.290072     0.402710
# 3    6        3       myopia_N     0.021846   -0.015325    -0.017809
# 4    6        4       myopia_N     0.025275   -0.016718    -0.019076
#
#            u_token
# 0       0_myopia_N
# 1  1_quad_injury_N
# 2     2_eye_exam_N
# 3       3_myopia_N
# 4       4_myopia_N

# %% [markdown]
# ## Save all combined results

# %%
output_path
# Out:
# './output/time_diff_toy_dataset_v3/event_based/30/lstm-att-lrp/test_results_all_5.pkl'

# %%
with open(output_path, 'wb') as fpath:
    pickle.dump(test_results, fpath)

# %%
! ls "./output/time_diff_toy_dataset_v3/event_based/30/lstm-att-lrp/"
# Out:
# model_weights		test_results_lrp_5.pkl	 val_results_lrp_5.pkl
# shap			test_results_shap_5.pkl  val_results_shap_5.pkl
# test_results_all_5.pkl	train_results
