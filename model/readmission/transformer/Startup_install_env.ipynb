# %%
# !pip install torchtext
# Out:
# Collecting torchtext
#   Downloading torchtext-0.7.0-cp36-cp36m-manylinux1_x86_64.whl (4.5 MB)
#      |████████████████████████████████| 4.5 MB 11.8 MB/s eta 0:00:01
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.91-cp36-cp36m-manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 63.0 MB/s eta 0:00:01
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages (from torchtext) (1.18.1)
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages (from torchtext) (2.22.0)
# Requirement already satisfied: torch in /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages (from torchtext) (1.6.0)
# Requirement already satisfied: tqdm in /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages (from torchtext) (4.42.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages (from requests->torchtext) (1.25.10)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages (from requests->torchtext) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages (from requests->torchtext) (2020.6.20)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages (from requests->torchtext) (2.8)
# Requirement already satisfied: future in /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages (from torch->torchtext) (0.18.2)
# Installing collected packages: sentencepiece, torchtext
# Successfully installed sentencepiece-0.1.91 torchtext-0.7.0
# WARNING: You are using pip version 20.0.2; however, version 20.2.3 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/pytorch_latest_p36/bin/python -m pip install --upgrade pip' command.

# %%
! conda install --yes black
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: -
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/linux-64::pandas==1.0.1=py36h0573a6f_0
#   - defaults/noarch::jupyterlab==1.2.6=pyhf63ae98_0
#   - defaults/linux-64::scikit-learn==0.22.1=py36hd81dba3_0
#   - defaults/linux-64::python-language-server==0.31.7=py36_0
#   - defaults/linux-64::bkcharts==0.2=py36_0
#   - defaults/linux-64::nb_conda==2.2.1=py36_0
#   - defaults/noarch::numpydoc==0.9.2=py_0
#   - defaults/linux-64::pytest-arraydiff==0.3=py36h39e3cac_0
#   - conda-forge/linux-64::cython-blis==0.4.1=py36h8c4c3a4_1
#   - defaults/linux-64::bottleneck==1.3.2=py36heb32a55_0
#   - defaults/noarch::sphinx==2.4.0=py_0
#   - defaults/linux-64::pywavelets==1.1.1=py36h7b6447c_0
#   - defaults/noarch::pytest-astropy==0.8.0=py_0
#   - fastai/noarch::fastcore==1.0.19=py_0
#   - defaults/linux-64::numexpr==2.7.1=py36h423224d_0
#   - defaults/noarch::anaconda-project==0.8.4=py_0
#   - defaults/linux-64::nbconvert==5.6.1=py36_0
#   - defaults/linux-64::h5py==2.10.0=py36h7918eee_0
#   - defaults/linux-64::bokeh==1.4.0=py36_0
#   - defaults/noarch::jupyterlab_server==1.0.6=py_0
#   - defaults/linux-64::numpy-base==1.18.1=py36hde5b4d6_1
#   - conda-forge/linux-64::thinc==7.4.1=py36hdb11119_0
#   - defaults/linux-64::jupyter==1.0.0=py36_7
#   - conda-forge/linux-64::spacy==2.3.2=py36hdb11119_0
#   - defaults/linux-64::astropy==4.0=py36h7b6447c_0
#   - defaults/linux-64::patsy==0.5.1=py36_0
#   - pytorch/linux-64::pytorch==1.6.0=py3.6_cuda10.1.243_cudnn7.6.3_0
#   - defaults/linux-64::scikit-image==0.16.2=py36h0573a6f_0
#   - defaults/linux-64::matplotlib-base==3.1.3=py36hef1b27d_0
#   - defaults/linux-64::imageio==2.6.1=py36_0
#   - pytorch/linux-64::torchvision==0.7.0=py36_cu101
#   - defaults/linux-64::pytables==3.6.1=py36h71ec239_0
#   - defaults/linux-64::nb_conda_kernels==2.2.4=py36_0
#   - defaults/linux-64::mkl_fft==1.0.15=py36ha843d7b_0
#   - defaults/linux-64::statsmodels==0.11.0=py36h7b6447c_0
#   - defaults/linux-64::spyder==4.0.1=py36_0
#   - defaults/noarch::seaborn==0.10.0=py_0
#   - defaults/linux-64::requests==2.22.0=py36_1
#   - defaults/linux-64::numba==0.48.0=py36h0573a6f_0
#   - defaults/linux-64::scipy==1.4.1=py36h0b6359f_0
#   - defaults/noarch::pytest-doctestplus==0.5.0=py_0
#   - defaults/linux-64::mkl_random==1.1.0=py36hd6b4f25_0
#   - fastai/noarch::fastprogress==1.0.0=pyh39e3cac_0
#   - defaults/noarch::dask==2.11.0=py_0
#   - defaults/noarch::ipywidgets==7.5.1=py_0
#   - defaults/linux-64::widgetsnbextension==3.5.1=py36_0
#   - defaults/noarch::s3fs==0.4.2=py_0
#   - fastai/noarch::fastai==2.0.15=py_0
#   - defaults/linux-64::notebook==6.0.3=py36_0
#   - defaults/linux-64::matplotlib==3.1.3=py36_0
#   - defaults/linux-64::anaconda-client==1.7.2=py36_0
#   - defaults/linux-64::numpy==1.18.1=py36h4f9e942_0
# failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: -
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/noarch::jupyterlab==1.2.6=pyhf63ae98_0
#   - defaults/linux-64::python-language-server==0.31.7=py36_0
#   - defaults/linux-64::nb_conda==2.2.1=py36_0
#   - defaults/noarch::numpydoc==0.9.2=py_0
#   - defaults/noarch::sphinx==2.4.0=py_0
#   - fastai/noarch::fastcore==1.0.19=py_0
#   - defaults/noarch::anaconda-project==0.8.4=py_0
#   - defaults/linux-64::nbconvert==5.6.1=py36_0
#   - defaults/noarch::jupyterlab_server==1.0.6=py_0
#   - defaults/linux-64::jupyter==1.0.0=py36_7
#   - conda-forge/linux-64::spacy==2.3.2=py36hdb11119_0
#   - defaults/linux-64::nb_conda_kernels==2.2.4=py36_0
#   - defaults/linux-64::spyder==4.0.1=py36_0
#   - defaults/linux-64::requests==2.22.0=py36_1
#   - fastai/noarch::fastprogress==1.0.0=pyh39e3cac_0
#   - defaults/noarch::ipywidgets==7.5.1=py_0
#   - defaults/linux-64::widgetsnbextension==3.5.1=py36_0
#   - defaults/noarch::s3fs==0.4.2=py_0
#   - fastai/noarch::fastai==2.0.15=py_0
#   - defaults/linux-64::notebook==6.0.3=py36_0
#   - defaults/linux-64::anaconda-client==1.7.2=py36_0
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.3
#   latest version: 4.9.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/ec2-user/anaconda3/envs/pytorch_latest_p36
#
#   added / updated specs:
#     - black
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     appdirs-1.4.4              |     pyh9f0ad1d_0          13 KB  conda-forge
#     astroid-2.4.2              |   py36h9f0ad1d_1         297 KB  conda-forge
#     black-19.10b0              |             py_4          83 KB  conda-forge
#     boto3-1.16.1               |     pyh9f0ad1d_0          69 KB  conda-forge
#     botocore-1.19.1            |     pyh9f0ad1d_0         4.1 MB  conda-forge
#     docutils-0.16              |   py36h9880bd3_2         736 KB  conda-forge
#     pathspec-0.8.0             |     pyh9f0ad1d_0          28 KB  conda-forge
#     pip-20.2.4                 |             py_0         1.1 MB  conda-forge
#     pylint-2.6.0               |   py36h9f0ad1d_1         446 KB  conda-forge
#     regex-2020.10.15           |   py36h8c4c3a4_0         360 KB  conda-forge
#     s3transfer-0.3.3           |             py_3          51 KB  conda-forge
#     urllib3-1.25.11            |             py_0          93 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         7.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   appdirs            conda-forge/noarch::appdirs-1.4.4-pyh9f0ad1d_0
#   astroid            conda-forge/linux-64::astroid-2.4.2-py36h9f0ad1d_1
#   black              conda-forge/noarch::black-19.10b0-py_4
#   bleach             conda-forge/noarch::bleach-3.2.1-pyh9f0ad1d_0
#   boto3              conda-forge/noarch::boto3-1.16.1-pyh9f0ad1d_0
#   botocore           conda-forge/noarch::botocore-1.19.1-pyh9f0ad1d_0
#   brotlipy           conda-forge/linux-64::brotlipy-0.7.0-py36he6145b8_1001
#   docutils           conda-forge/linux-64::docutils-0.16-py36h9880bd3_2
#   pathspec           conda-forge/noarch::pathspec-0.8.0-pyh9f0ad1d_0
#   pip                conda-forge/noarch::pip-20.2.4-py_0
#   pylint             conda-forge/linux-64::pylint-2.6.0-py36h9f0ad1d_1
#   regex              conda-forge/linux-64::regex-2020.10.15-py36h8c4c3a4_0
#   s3transfer         conda-forge/noarch::s3transfer-0.3.3-py_3
#   toml               conda-forge/noarch::toml-0.10.1-pyh9f0ad1d_0
#   urllib3            conda-forge/noarch::urllib3-1.25.11-py_0
#
# The following packages will be UPDATED:
#
#   certifi                          2020.6.20-py36h9f0ad1d_0 --> 2020.6.20-py36h9880bd3_2
#
#
#
# Downloading and Extracting Packages
# pip-20.2.4           | 1.1 MB    | ##################################### | 100%
# pylint-2.6.0         | 446 KB    | ##################################### | 100%
# astroid-2.4.2        | 297 KB    | ##################################### | 100%
# appdirs-1.4.4        | 13 KB     | ##################################### | 100%
# s3transfer-0.3.3     | 51 KB     | ##################################### | 100%
# pathspec-0.8.0       | 28 KB     | ##################################### | 100%
# black-19.10b0        | 83 KB     | ##################################### | 100%
# urllib3-1.25.11      | 93 KB     | ##################################### | 100%
# regex-2020.10.15     | 360 KB    | ##################################### | 100%
# botocore-1.19.1      | 4.1 MB    | ##################################### | 100%
# docutils-0.16        | 736 KB    | ##################################### | 100%
# boto3-1.16.1         | 69 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
! jupyter nbextension install https://github.com/drillan/jupyter-black/archive/master.zip --user
! jupyter nbextension enable jupyter-black-master/jupyter-black
# Out:
# Downloading: https://github.com/drillan/jupyter-black/archive/master.zip -> /tmp/tmpwhe0q7fy/master.zip
# Extracting: /tmp/tmpwhe0q7fy/master.zip -> /home/ec2-user/.local/share/jupyter/nbextensions
# Enabling notebook extension jupyter-black-master/jupyter-black...
#       - Validating: OK

# %%
! pip install flake8 pycodestyle_magic
# %load_ext pycodestyle_magic
# %flake8_on --ignore F403,F404,F405,E501,E203,W503,W293,W291
# Out:
# Requirement already satisfied: flake8 in /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages (3.7.9)
# Collecting pycodestyle_magic
#   Downloading pycodestyle_magic-0.5-py2.py3-none-any.whl (9.5 kB)
# Requirement already satisfied: pyflakes<2.2.0,>=2.1.0 in /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages (from flake8) (2.1.1)
# Requirement already satisfied: mccabe<0.7.0,>=0.6.0 in /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages (from flake8) (0.6.1)
# Requirement already satisfied: pycodestyle<2.6.0,>=2.5.0 in /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages (from flake8) (2.5.0)
# Requirement already satisfied: entrypoints<0.4.0,>=0.3.0 in /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages (from flake8) (0.3)
# Installing collected packages: pycodestyle-magic
# Successfully installed pycodestyle-magic-0.5

# %%
! sudo yum -y install yes htop
# Out:
# Loaded plugins: dkms-build-requires, priorities, update-motd, upgrade-helper,
#               : versionlock
# amzn-main                                                | 2.1 kB     00:00
# amzn-updates                                             | 3.8 kB     00:00
# copr:copr.fedorainfracloud.org:vbatts:shadow-utils-newxi | 3.0 kB     00:00
# libnvidia-container/x86_64/signature                     |  488 B     00:00
# libnvidia-container/x86_64/signature                     | 2.1 kB     00:00 !!!
# nvidia-container-runtime/x86_64/signature                |  488 B     00:00
# nvidia-container-runtime/x86_64/signature                | 2.1 kB     00:00 !!!
# nvidia-docker/x86_64/signature                           |  488 B     00:00
# nvidia-docker/x86_64/signature                           | 2.1 kB     00:00 !!!
# No package yes available.
# Resolving Dependencies
# --> Running transaction check
# ---> Package htop.x86_64 0:1.0.1-2.3.amzn1 will be installed
# --> Finished Dependency Resolution
#
# Dependencies Resolved
#
# ================================================================================
#  Package      Arch           Version                    Repository         Size
# ================================================================================
# Installing:
#  htop         x86_64         1.0.1-2.3.amzn1            amzn-main          81 k
#
# Transaction Summary
# ================================================================================
# Install  1 Package
#
# Total download size: 81 k
# Installed size: 158 k
# Downloading packages:
# htop-1.0.1-2.3.amzn1.x86_64.rpm                            |  81 kB   00:00
# Running transaction check
# Running transaction test
# Transaction test succeeded
# Running transaction
#   Installing : htop-1.0.1-2.3.amzn1.x86_64                                  1/1
#   Verifying  : htop-1.0.1-2.3.amzn1.x86_64                                  1/1
#
# Installed:
#   htop.x86_64 0:1.0.1-2.3.amzn1
#
# Complete!
