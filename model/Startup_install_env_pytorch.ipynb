# %%
# !conda update --yes -n base conda
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: -
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/noarch::numpydoc==0.9.2=py_0
#   - defaults/noarch::sphinx==2.4.0=py_0
#   - defaults/noarch::boto3==1.9.162=py_0
#   - defaults/noarch::botocore==1.12.189=py_0
#   - defaults/linux-64::python-language-server==0.31.7=py37_0
#   - defaults/linux-64::s3transfer==0.2.1=py37_0
#   - defaults/linux-64::spyder==4.0.1=py37_0
#   - defaults/noarch::s3fs==0.4.2=py_0
# done
#
# ## Package Plan ##
#
#   environment location: /home/ec2-user/anaconda3
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     astroid-2.4.2              |   py37hc8dfbb8_1         291 KB  conda-forge
#     backports.tempfile-1.0     |             py_0          10 KB  conda-forge
#     backports.weakref-1.0.post1|py37hc8dfbb8_1002           8 KB  conda-forge
#     certifi-2020.12.5          |   py37h89c1867_1         143 KB  conda-forge
#     conda-4.9.2                |   py37h89c1867_0         3.0 MB  conda-forge
#     conda-package-handling-1.7.2|   py37hb5d75c8_0         915 KB  conda-forge
#     docutils-0.16              |   py37h89c1867_3         739 KB  conda-forge
#     pylint-2.6.0               |   py37hc8dfbb8_1         451 KB  conda-forge
#     toml-0.10.2                |     pyhd8ed1ab_0          18 KB  conda-forge
#     typed-ast-1.4.2            |   py37h27cfd23_1         185 KB
#     xmltodict-0.12.0           |             py_0          11 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         5.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   astroid            conda-forge/linux-64::astroid-2.4.2-py37hc8dfbb8_1
#   docutils           conda-forge/linux-64::docutils-0.16-py37h89c1867_3
#   pylint             conda-forge/linux-64::pylint-2.6.0-py37hc8dfbb8_1
#   toml               conda-forge/noarch::toml-0.10.2-pyhd8ed1ab_0
#   typed-ast          pkgs/main/linux-64::typed-ast-1.4.2-py37h27cfd23_1
#
# The following packages will be UPDATED:
#
#   backports.weakref  pkgs/main/noarch::backports.weakref-1~ --> conda-forge/linux-64::backports.weakref-1.0.post1-py37hc8dfbb8_1002
#   ca-certificates                      2020.11.8-ha878542_0 --> 2020.12.5-ha878542_0
#   certifi                          2020.11.8-py37h89c1867_0 --> 2020.12.5-py37h89c1867_1
#   conda                                4.8.4-py37hc8dfbb8_2 --> 4.9.2-py37h89c1867_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   backports.functoo~ pkgs/main::backports.functools_lru_ca~ --> conda-forge::backports.functools_lru_cache-1.6.1-py_0
#   backports.tempfile pkgs/main::backports.tempfile-1.0-py_1 --> conda-forge::backports.tempfile-1.0-py_0
#   conda-package-han~ pkgs/main::conda-package-handling-1.7~ --> conda-forge::conda-package-handling-1.7.2-py37hb5d75c8_0
#   xmltodict                                       pkgs/main --> conda-forge
#
#
#
# Downloading and Extracting Packages
# certifi-2020.12.5    | 143 KB    | ##################################### | 100%
# backports.weakref-1. | 8 KB      | ##################################### | 100%
# astroid-2.4.2        | 291 KB    | ##################################### | 100%
# toml-0.10.2          | 18 KB     | ##################################### | 100%
# typed-ast-1.4.2      | 185 KB    | ##################################### | 100%
# docutils-0.16        | 739 KB    | ##################################### | 100%
# pylint-2.6.0         | 451 KB    | ##################################### | 100%
# xmltodict-0.12.0     | 11 KB     | ##################################### | 100%
# conda-4.9.2          | 3.0 MB    | ##################################### | 100%
# conda-package-handli | 915 KB    | ##################################### | 100%
# backports.tempfile-1 | 10 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# !conda install --yes black
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: |
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/linux-64::pandas==1.0.1=py36h0573a6f_0
#   - defaults/noarch::jupyterlab==1.2.6=pyhf63ae98_0
#   - defaults/linux-64::scikit-learn==0.22.1=py36hd81dba3_0
#   - defaults/linux-64::python-language-server==0.31.7=py36_0
#   - defaults/linux-64::bkcharts==0.2=py36_0
#   - defaults/linux-64::nb_conda==2.2.1=py36_0
#   - defaults/noarch::numpydoc==0.9.2=py_0
#   - defaults/linux-64::pytest-arraydiff==0.3=py36h39e3cac_0
#   - defaults/linux-64::bottleneck==1.3.2=py36heb32a55_0
#   - defaults/noarch::sphinx==2.4.0=py_0
#   - defaults/linux-64::pywavelets==1.1.1=py36h7b6447c_0
#   - defaults/noarch::pytest-astropy==0.8.0=py_0
#   - defaults/linux-64::numexpr==2.7.1=py36h423224d_0
#   - defaults/noarch::anaconda-project==0.8.4=py_0
#   - defaults/noarch::boto3==1.9.162=py_0
#   - defaults/linux-64::s3transfer==0.2.1=py36_0
#   - defaults/linux-64::nbconvert==5.6.1=py36_0
#   - defaults/linux-64::h5py==2.10.0=py36h7918eee_0
#   - defaults/linux-64::bokeh==1.4.0=py36_0
#   - defaults/noarch::jupyterlab_server==1.0.6=py_0
#   - defaults/linux-64::numpy-base==1.18.1=py36hde5b4d6_1
#   - conda-forge/linux-64::thinc==7.4.3=py36h8e82bdb_0
#   - defaults/noarch::botocore==1.12.189=py_0
#   - defaults/linux-64::jupyter==1.0.0=py36_7
#   - defaults/linux-64::astropy==4.0=py36h7b6447c_0
#   - defaults/linux-64::patsy==0.5.1=py36_0
#   - defaults/linux-64::scikit-image==0.16.2=py36h0573a6f_0
#   - pytorch/linux-64::pytorch==1.4.0=py3.6_cuda10.1.243_cudnn7.6.3_0
#   - defaults/linux-64::matplotlib-base==3.1.3=py36hef1b27d_0
#   - defaults/linux-64::imageio==2.6.1=py36_0
#   - defaults/linux-64::pytables==3.6.1=py36h71ec239_0
#   - defaults/linux-64::nb_conda_kernels==2.2.4=py36_0
#   - defaults/linux-64::mkl_fft==1.0.15=py36ha843d7b_0
#   - defaults/linux-64::statsmodels==0.11.0=py36h7b6447c_0
#   - defaults/linux-64::spyder==4.0.1=py36_0
#   - defaults/noarch::seaborn==0.10.0=py_0
#   - defaults/linux-64::requests==2.22.0=py36_1
#   - defaults/linux-64::numba==0.48.0=py36h0573a6f_0
#   - defaults/linux-64::scipy==1.4.1=py36h0b6359f_0
#   - defaults/noarch::pytest-doctestplus==0.5.0=py_0
#   - defaults/linux-64::mkl_random==1.1.0=py36hd6b4f25_0
#   - conda-forge/linux-64::spacy==2.3.4=py36h8e82bdb_0
#   - fastai/noarch::fastprogress==1.0.0=pyh39e3cac_0
#   - defaults/noarch::dask==2.11.0=py_0
#   - defaults/noarch::ipywidgets==7.5.1=py_0
#   - defaults/linux-64::widgetsnbextension==3.5.1=py36_0
#   - defaults/noarch::s3fs==0.4.2=py_0
#   - defaults/linux-64::notebook==6.0.3=py36_0
#   - pytorch/linux-64::torchvision==0.5.0=py36_cu101
#   - conda-forge/linux-64::cython-blis==0.7.3=py36ha112f06_0
#   - defaults/linux-64::matplotlib==3.1.3=py36_0
#   - defaults/linux-64::anaconda-client==1.7.2=py36_0
#   - fastai/noarch::fastai==1.0.61=1
#   - defaults/linux-64::numpy==1.18.1=py36h4f9e942_0
# failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: \
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/noarch::jupyterlab==1.2.6=pyhf63ae98_0
#   - defaults/linux-64::python-language-server==0.31.7=py36_0
#   - defaults/linux-64::nb_conda==2.2.1=py36_0
#   - defaults/noarch::numpydoc==0.9.2=py_0
#   - defaults/noarch::sphinx==2.4.0=py_0
#   - defaults/noarch::anaconda-project==0.8.4=py_0
#   - defaults/noarch::boto3==1.9.162=py_0
#   - defaults/linux-64::s3transfer==0.2.1=py36_0
#   - defaults/linux-64::nbconvert==5.6.1=py36_0
#   - defaults/noarch::jupyterlab_server==1.0.6=py_0
#   - defaults/noarch::botocore==1.12.189=py_0
#   - defaults/linux-64::jupyter==1.0.0=py36_7
#   - defaults/linux-64::nb_conda_kernels==2.2.4=py36_0
#   - defaults/linux-64::spyder==4.0.1=py36_0
#   - defaults/linux-64::requests==2.22.0=py36_1
#   - conda-forge/linux-64::spacy==2.3.4=py36h8e82bdb_0
#   - fastai/noarch::fastprogress==1.0.0=pyh39e3cac_0
#   - defaults/noarch::ipywidgets==7.5.1=py_0
#   - defaults/linux-64::widgetsnbextension==3.5.1=py36_0
#   - defaults/noarch::s3fs==0.4.2=py_0
#   - defaults/linux-64::notebook==6.0.3=py36_0
#   - defaults/linux-64::anaconda-client==1.7.2=py36_0
#   - fastai/noarch::fastai==1.0.61=1
# done
#
# ## Package Plan ##
#
#   environment location: /home/ec2-user/anaconda3/envs/pytorch_p36
#
#   added / updated specs:
#     - black
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     appdirs-1.4.4              |     pyh9f0ad1d_0          13 KB  conda-forge
#     astroid-2.4.2              |   py36h9f0ad1d_1         297 KB  conda-forge
#     black-19.10b0              |             py_4          83 KB  conda-forge
#     bleach-3.2.3               |     pyh44b312d_0         111 KB  conda-forge
#     certifi-2020.12.5          |   py36h5fab9bb_1         143 KB  conda-forge
#     dataclasses-0.7            |     pyhe4b4509_6          21 KB  conda-forge
#     docutils-0.16              |   py36h5fab9bb_3         738 KB  conda-forge
#     pathspec-0.8.1             |     pyhd3deb0d_0          29 KB  conda-forge
#     pip-21.0                   |     pyhd8ed1ab_0         1.1 MB  conda-forge
#     pylint-2.6.0               |   py36h9f0ad1d_1         446 KB  conda-forge
#     regex-2020.11.13           |   py36h1d69622_0         358 KB  conda-forge
#     urllib3-1.25.11            |             py_0          93 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   appdirs            conda-forge/noarch::appdirs-1.4.4-pyh9f0ad1d_0
#   astroid            conda-forge/linux-64::astroid-2.4.2-py36h9f0ad1d_1
#   black              conda-forge/noarch::black-19.10b0-py_4
#   bleach             conda-forge/noarch::bleach-3.2.3-pyh44b312d_0
#   brotlipy           conda-forge/linux-64::brotlipy-0.7.0-py36he6145b8_1001
#   dataclasses        conda-forge/noarch::dataclasses-0.7-pyhe4b4509_6
#   docutils           conda-forge/linux-64::docutils-0.16-py36h5fab9bb_3
#   pathspec           conda-forge/noarch::pathspec-0.8.1-pyhd3deb0d_0
#   pip                conda-forge/noarch::pip-21.0-pyhd8ed1ab_0
#   pylint             conda-forge/linux-64::pylint-2.6.0-py36h9f0ad1d_1
#   regex              conda-forge/linux-64::regex-2020.11.13-py36h1d69622_0
#   toml               conda-forge/noarch::toml-0.10.2-pyhd8ed1ab_0
#   urllib3            conda-forge/noarch::urllib3-1.25.11-py_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2020.11.8-ha878542_0 --> 2020.12.5-ha878542_0
#   certifi                          2020.11.8-py36h5fab9bb_0 --> 2020.12.5-py36h5fab9bb_1
#
#
#
# Downloading and Extracting Packages
# regex-2020.11.13     | 358 KB    | ##################################### | 100%
# pylint-2.6.0         | 446 KB    | ##################################### | 100%
# appdirs-1.4.4        | 13 KB     | ##################################### | 100%
# docutils-0.16        | 738 KB    | ##################################### | 100%
# astroid-2.4.2        | 297 KB    | ##################################### | 100%
# pip-21.0             | 1.1 MB    | ##################################### | 100%
# black-19.10b0        | 83 KB     | ##################################### | 100%
# urllib3-1.25.11      | 93 KB     | ##################################### | 100%
# certifi-2020.12.5    | 143 KB    | ##################################### | 100%
# pathspec-0.8.1       | 29 KB     | ##################################### | 100%
# bleach-3.2.3         | 111 KB    | ##################################### | 100%
# dataclasses-0.7      | 21 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
! jupyter nbextension install https://github.com/drillan/jupyter-black/archive/master.zip --user
! jupyter nbextension enable jupyter-black-master/jupyter-black
# Out:
# Downloading: https://github.com/drillan/jupyter-black/archive/master.zip -> /tmp/tmppcas7ci2/master.zip
# Extracting: /tmp/tmppcas7ci2/master.zip -> /home/ec2-user/.local/share/jupyter/nbextensions
# Enabling notebook extension jupyter-black-master/jupyter-black...
#       - Validating: OK

# %%
! pip install flake8 pycodestyle_magic
# %load_ext pycodestyle_magic
# %flake8_on --ignore F403,F404,F405,E501,E203,W503,W293,W291
# Out:
# Requirement already satisfied: flake8 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (3.7.9)
# Collecting pycodestyle_magic
#   Downloading pycodestyle_magic-0.5-py2.py3-none-any.whl (9.5 kB)
# Requirement already satisfied: pycodestyle<2.6.0,>=2.5.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from flake8) (2.5.0)
# Requirement already satisfied: pyflakes<2.2.0,>=2.1.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from flake8) (2.1.1)
# Requirement already satisfied: mccabe<0.7.0,>=0.6.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from flake8) (0.6.1)
# Requirement already satisfied: entrypoints<0.4.0,>=0.3.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from flake8) (0.3)
# Installing collected packages: pycodestyle-magic
# Successfully installed pycodestyle-magic-0.5

# %%
! sudo yum -y install yes htop
# Out:
# Loaded plugins: dkms-build-requires, priorities, update-motd, upgrade-helper,
#               : versionlock
# amzn-main                                                | 2.1 kB     00:00
# amzn-updates                                             | 3.8 kB     00:00
# No package yes available.
# Resolving Dependencies
# --> Running transaction check
# ---> Package htop.x86_64 0:1.0.1-2.3.amzn1 will be installed
# --> Finished Dependency Resolution
#
# Dependencies Resolved
#
# ================================================================================
#  Package      Arch           Version                    Repository         Size
# ================================================================================
# Installing:
#  htop         x86_64         1.0.1-2.3.amzn1            amzn-main          81 k
#
# Transaction Summary
# ================================================================================
# Install  1 Package
#
# Total download size: 81 k
# Installed size: 158 k
# Downloading packages:
# htop-1.0.1-2.3.amzn1.x86_64.rpm                            |  81 kB   00:00
# Running transaction check
# Running transaction test
# Transaction test succeeded
# Running transaction
#   Installing : htop-1.0.1-2.3.amzn1.x86_64                                  1/1
#   Verifying  : htop-1.0.1-2.3.amzn1.x86_64                                  1/1
#
# Installed:
#   htop.x86_64 0:1.0.1-2.3.amzn1
#
# Complete!

# %%
# !conda install seaborn --yes
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: -
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/linux-64::pandas==1.0.1=py36h0573a6f_0
#   - defaults/linux-64::scikit-learn==0.22.1=py36hd81dba3_0
#   - defaults/linux-64::bkcharts==0.2=py36_0
#   - defaults/linux-64::pytest-arraydiff==0.3=py36h39e3cac_0
#   - defaults/linux-64::bottleneck==1.3.2=py36heb32a55_0
#   - defaults/linux-64::pywavelets==1.1.1=py36h7b6447c_0
#   - defaults/noarch::pytest-astropy==0.8.0=py_0
#   - defaults/linux-64::numexpr==2.7.1=py36h423224d_0
#   - defaults/linux-64::h5py==2.10.0=py36h7918eee_0
#   - defaults/linux-64::bokeh==1.4.0=py36_0
#   - defaults/linux-64::numpy-base==1.18.1=py36hde5b4d6_1
#   - conda-forge/linux-64::thinc==7.4.3=py36h8e82bdb_0
#   - defaults/linux-64::astropy==4.0=py36h7b6447c_0
#   - defaults/linux-64::patsy==0.5.1=py36_0
#   - defaults/linux-64::scikit-image==0.16.2=py36h0573a6f_0
#   - pytorch/linux-64::pytorch==1.4.0=py3.6_cuda10.1.243_cudnn7.6.3_0
#   - defaults/linux-64::matplotlib-base==3.1.3=py36hef1b27d_0
#   - defaults/linux-64::imageio==2.6.1=py36_0
#   - defaults/linux-64::pytables==3.6.1=py36h71ec239_0
#   - defaults/linux-64::mkl_fft==1.0.15=py36ha843d7b_0
#   - defaults/linux-64::statsmodels==0.11.0=py36h7b6447c_0
#   - defaults/noarch::seaborn==0.10.0=py_0
#   - defaults/linux-64::numba==0.48.0=py36h0573a6f_0
#   - defaults/linux-64::scipy==1.4.1=py36h0b6359f_0
#   - defaults/noarch::pytest-doctestplus==0.5.0=py_0
#   - defaults/linux-64::mkl_random==1.1.0=py36hd6b4f25_0
#   - conda-forge/linux-64::spacy==2.3.4=py36h8e82bdb_0
#   - fastai/noarch::fastprogress==1.0.0=pyh39e3cac_0
#   - defaults/noarch::dask==2.11.0=py_0
#   - pytorch/linux-64::torchvision==0.5.0=py36_cu101
#   - conda-forge/linux-64::cython-blis==0.7.3=py36ha112f06_0
#   - defaults/linux-64::matplotlib==3.1.3=py36_0
#   - fastai/noarch::fastai==1.0.61=1
#   - defaults/linux-64::numpy==1.18.1=py36h4f9e942_0
# failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/ec2-user/anaconda3/envs/pytorch_p36
#
#   added / updated specs:
#     - seaborn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     astroid-2.3.3              |           py36_0         272 KB
#     bleach-3.1.0               |           py36_0         221 KB
#     pip-20.0.2                 |           py36_1         1.7 MB
#     pylint-2.4.4               |           py36_0         422 KB
#     seaborn-0.11.1             |       ha770c72_0           4 KB  conda-forge
#     seaborn-base-0.11.1        |     pyhd8ed1ab_0         218 KB  conda-forge
#     urllib3-1.25.8             |           py36_0         169 KB
#     ------------------------------------------------------------
#                                            Total:         3.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   seaborn-base       conda-forge/noarch::seaborn-base-0.11.1-pyhd8ed1ab_0
#
# The following packages will be UPDATED:
#
#   seaborn             pkgs/main/noarch::seaborn-0.10.0-py_0 --> conda-forge/linux-64::seaborn-0.11.1-ha770c72_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   astroid            conda-forge::astroid-2.4.2-py36h9f0ad~ --> pkgs/main::astroid-2.3.3-py36_0
#   bleach             conda-forge/noarch::bleach-3.2.3-pyh4~ --> pkgs/main/linux-64::bleach-3.1.0-py36_0
#   docutils           conda-forge::docutils-0.16-py36h5fab9~ --> pkgs/main::docutils-0.16-py36_0
#   pip                conda-forge/noarch::pip-21.0-pyhd8ed1~ --> pkgs/main/linux-64::pip-20.0.2-py36_1
#   pylint             conda-forge::pylint-2.6.0-py36h9f0ad1~ --> pkgs/main::pylint-2.4.4-py36_0
#   urllib3            conda-forge/noarch::urllib3-1.25.11-p~ --> pkgs/main/linux-64::urllib3-1.25.8-py36_0
#
#
#
# Downloading and Extracting Packages
# bleach-3.1.0         | 221 KB    | ##################################### | 100%
# astroid-2.3.3        | 272 KB    | ##################################### | 100%
# pip-20.0.2           | 1.7 MB    | ##################################### | 100%
# pylint-2.4.4         | 422 KB    | ##################################### | 100%
# seaborn-base-0.11.1  | 218 KB    | ##################################### | 100%
# seaborn-0.11.1       | 4 KB      | ##################################### | 100%
# urllib3-1.25.8       | 169 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
conda install -c conda-forge shap
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: |
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/linux-64::pandas==1.0.1=py36h0573a6f_0
#   - defaults/linux-64::scikit-learn==0.22.1=py36hd81dba3_0
#   - defaults/linux-64::bkcharts==0.2=py36_0
#   - defaults/linux-64::pytest-arraydiff==0.3=py36h39e3cac_0
#   - defaults/linux-64::bottleneck==1.3.2=py36heb32a55_0
#   - defaults/linux-64::pywavelets==1.1.1=py36h7b6447c_0
#   - defaults/noarch::pytest-astropy==0.8.0=py_0
#   - defaults/linux-64::numexpr==2.7.1=py36h423224d_0
#   - defaults/linux-64::h5py==2.10.0=py36h7918eee_0
#   - defaults/linux-64::bokeh==1.4.0=py36_0
#   - defaults/linux-64::numpy-base==1.18.1=py36hde5b4d6_1
#   - conda-forge/linux-64::thinc==7.4.3=py36h8e82bdb_0
#   - defaults/linux-64::astropy==4.0=py36h7b6447c_0
#   - defaults/linux-64::patsy==0.5.1=py36_0
#   - defaults/linux-64::scikit-image==0.16.2=py36h0573a6f_0
#   - pytorch/linux-64::pytorch==1.4.0=py3.6_cuda10.1.243_cudnn7.6.3_0
#   - defaults/linux-64::matplotlib-base==3.1.3=py36hef1b27d_0
#   - defaults/linux-64::imageio==2.6.1=py36_0
#   - defaults/linux-64::pytables==3.6.1=py36h71ec239_0
#   - conda-forge/linux-64::seaborn==0.11.1=ha770c72_0
#   - defaults/linux-64::mkl_fft==1.0.15=py36ha843d7b_0
#   - defaults/linux-64::statsmodels==0.11.0=py36h7b6447c_0
#   - defaults/linux-64::numba==0.48.0=py36h0573a6f_0
#   - defaults/linux-64::scipy==1.4.1=py36h0b6359f_0
#   - defaults/noarch::pytest-doctestplus==0.5.0=py_0
#   - defaults/linux-64::mkl_random==1.1.0=py36hd6b4f25_0
#   - conda-forge/linux-64::spacy==2.3.4=py36h8e82bdb_0
#   - fastai/noarch::fastprogress==1.0.0=pyh39e3cac_0
#   - defaults/noarch::dask==2.11.0=py_0
#   - conda-forge/noarch::seaborn-base==0.11.1=pyhd8ed1ab_0
#   - pytorch/linux-64::torchvision==0.5.0=py36_cu101
#   - conda-forge/linux-64::cython-blis==0.7.3=py36ha112f06_0
#   - defaults/linux-64::matplotlib==3.1.3=py36_0
#   - fastai/noarch::fastai==1.0.61=1
#   - defaults/linux-64::numpy==1.18.1=py36h4f9e942_0
# failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/ec2-user/anaconda3/envs/pytorch_p36
#
#   added / updated specs:
#     - shap
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     shap-0.37.0                |   py36hd87012b_0         510 KB  conda-forge
#     slicer-0.0.7               |     pyhd8ed1ab_0          16 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         527 KB
#
# The following NEW packages will be INSTALLED:
#
#   shap               conda-forge/linux-64::shap-0.37.0-py36hd87012b_0
#   slicer             conda-forge/noarch::slicer-0.0.7-pyhd8ed1ab_0
#
#
#
# Downloading and Extracting Packages
# slicer-0.0.7         | 16 KB     | ##################################### | 100%
# shap-0.37.0          | 510 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.
# 13: E999 SyntaxError: invalid syntax
# 1:16: E225 missing whitespace around operator

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-1.3.3-py3-none-manylinux2010_x86_64.whl (157.5 MB)
#      |████████████████████████████████| 157.5 MB 45 kB/s s eta 0:00:01    |██████                          | 29.1 MB 17.0 MB/s eta 0:00:08
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from xgboost) (1.19.4)
# Requirement already satisfied: scipy in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from xgboost) (1.4.1)
# Installing collected packages: xgboost
# Successfully installed xgboost-1.3.3
# WARNING: You are using pip version 20.3; however, version 21.0 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/pytorch_p36/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install -e git+https://github.com/changyaochen/rbo.git@master#egg=rbo
# Out:
# Obtaining rbo from git+https://github.com/changyaochen/rbo.git@master#egg=rbo
#   Cloning https://github.com/changyaochen/rbo.git (to revision master) to ./src/rbo
#   Running command git clone -q https://github.com/changyaochen/rbo.git /home/ec2-user/SageMaker/CMSAI_Research/model/src/rbo
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from rbo) (1.19.4)
# Installing collected packages: rbo
#   Running setup.py develop for rbo
# Successfully installed rbo
# WARNING: You are using pip version 20.3; however, version 21.0 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/pytorch_p36/bin/python -m pip install --upgrade pip' command.
